# %% [markdown]
# # Tutorial 1: Corpora and Vector Spaces
# See this *gensim* tutorial on the web [here](https://radimrehurek.com/gensim/tut1.html).

# %% [markdown]
# Don’t forget to set:

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import os
import tempfile
import codecs
TEMP_FOLDER = tempfile.gettempdir()
print('Folder "{}" will be used to save temporary dictionary and corpus.'.format(TEMP_FOLDER))
# Out:
# Folder "/tmp" will be used to save temporary dictionary and corpus.

# %% [markdown]
# if you want to see logging events.
#
# ## From Strings to Vectors
#
# This time, let’s start from documents represented as strings:

# %%
from gensim import corpora

# %%
language = 'de'
documents = []
directory = "../corpus_samples/OCRd/ALL_DE/processed/"
filename = directory + language +'.txt'
with codecs.open(filename, encoding='utf_8') as f:
  documents = f.readlines()
print(documents[4])
# Out:
# Passageninstrument III Stand setzen Chrono- graph reinigen Samoa mehrer zurück- gebracht 8-zöllige Universal Möglichkeit renovieren Entwurf 10-zölliges Universal 8-zöllig gedenken arbeiten Verschiedene Umänderungen Hilfe nötigen Turmbeobachtungen hydrostatische Nivellementsanlage Erdbebeninstrumente Uhr Elektromotor Umwandlung Stadt geliefert Drehstrom Gleichstrom betreiben Zifferblätter dienen Teilkreis- untersucher Jäderinapparat neu Nivellierinstrument Nickelstahl Kühnens angeben erbauen alt Meißner und so weiter groß Arbeit verursachen Anfertigung Er- schütterungsmessers Eisenbahnverwaltung angeben Dr. Schweydar Nächstdem letzt begonnen Nivellierlatten Nickelstahl Verpackung fertigstellen Lineal Zelluloid arbeiten Juni Heimert -aumerae Königl Preußische Geodätische Institut FOLGE Nummer Jahresbericht Direktor Königliche Geodätische Institut April April Potsdam drucken Stankiewiez Buchdruckerei G.m Berlin Exzellenz Königliche Staatsminister Minister geistlich Unterrichts-Angelegenheiten Herrn Trott Solz gehorsamst überreichen Jahresbericht Direktor Königliche Geodätische Institut April April sächlichen ausgeben belaufen Verwendung folgen stellen Tagegelder Reisekosten Stations- beobachtungen außerhalb Beobachtung verbunden ausgeben außerordentlich Rechenarbeiten Schreibhilfe verschieden Reise Verwaltung Dotationsfonds Heizmaterial Heizen Reinigen Diensträume Druckkosten dergl Buch Zeitschrift dergl Porto Schreibmaterial Instandhaltung Abänderung Anschaffung Untersuchung Instrument aus- wärtige Mechaniker und so weiter -für mechanische Werkstatt photo- graphische Kammer einschließlich Gehilfenlöhne Material verschieden Mobiliarbeschaffungen insgemein wissenschaftliche Personal Institut bestand Direktor folgend Herr Abteilungsvorsteher Geh Reg.-Rat Professor Dr. Dr.-Ing Albrecht Professor Dr. Krüger Professor Borraß Professor Dr. Kühne Professor Dr. Galle Observatoren Professor Schnauder Professor Haasemann Professor .B. Wanach Professor Dr. Flotow Dr. Schweydar Dr. Förster wissenschaftlich Hilfsarbeiter Otto Meißner Dr. Bolte Rechenarbeiten Hilfeleistungen Vorjahr beschäftigen Sekretär Herr Auel Herr Obst fern Herr Dr. Hübner Oktober Herr Dr. Paul Adrian Mitte Juli Herr Landmesser Hildner zeitweise Herr Gutermann Herr Landmesser Ferdinand Müller Hierzu tritt international Erdmessung insbesondere Breitendienst beschäftigen Hilfspersonal Verlust erleiden Institut Juni erfolgen Tod Bureauvorstehers Herrn Eugen Mendelson hindurch eifern groß Geschick Obliegenheiten Sekretär Institut Zentral- bureaus Internationale Erdmessung Verwalter Fond letztgenannt Institution erfüllen Instrument beschaffen Vertikalseismograph Spindler Hoyer Göttingen elektrische Heizeinrichtung einschl Elektromotor Toepfer Sohn Potsdam Nickelstahlbänder Fueß Steglitz Wickelmaschine Thiele Potsdam Repulsionsmotor Siemens-Schuckert Berlin Gleichstrom-Generator Rechentafel Schieber Reiß Liebenwerda Meßband Pegelstationen Warnemünde Trave- münden Wismar Fueß Steglitz Zelluloid Schutzdecken Teilung Nickelstahl- Nivellierlatten Sickler Karlsruhe Laterne Graumann Potsdam Be- obachtungen Brunnenkammer Glasskala Ablesen Ordinaten Fueß Steglitz Ferner Institut Empfangsstation draht- lose Telegraphie Beobachtung Zeitsignale Norddeich Eiffelturm versehen Anlage Leitung Mitwirkung Herrn Professor Wanach erfolgen Mechaniker Herrn Fechner Passagen- instrument Nummer neu Fernrohr Prismenstuhl neu Azimutalbewegung versehen Ausgeliehen Heliotrope Kolonialamt Zenit- kamera Sternwarte Göttingen Mitschwingungs- dynamometer Herrn Dr. Fagerholm Dreipendelapparat Stückrath Pendel Koinzidenzapparat Halbsekundenpendeluhr Strasser Rhode Nummer British Antaretic Expedition Nivellierinstrument Herrn Ge- heimrat Professor Dr. Hecker Straßburg Original- pendelapparat Sternecks Deutsche Museum Meister- werken Naturwissenschaft Technik Ferner ausleihen Universal Instrument Heyde Nummer Stativ Herrn Admiralitätsrat Professor Dr. Kohlschütter vollständig Barometer Apparat Schwere- messungen  ...

# %% [markdown]
# This is a tiny corpus of nine documents, each consisting of only a single sentence.
#
# First, let’s tokenize the documents, remove common words (using a toy stoplist) as well as words that only appear once in the corpus:

# %%
# remove common words and tokenize
texts = [[word for word in document.split()]
         for document in documents]

# remove words that appear only once
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1] for text in texts]

from pprint import pprint  # pretty-printer
pprint(texts)
# Out:
# [['Protokoll',
#   'Verhandlung',
#   'permanent',
#   'Commission',
#   'Europäische',
#   'Gradmessung',
#   'September',
#   'WIEN',
#   'Manuscript',
#   'drucken',
#   'Protokoll',
#   'Verhandlung',
#   'permanent',
#   'Commission',
#   'Europäische',
#   'Gradmessung',
#   'September',
#   'WIEN',
#   'Manuscript',
#   'drucken',
#   'Sitzung',
#   'permanent',
#   'Commission',
#   'Verhandelt',
#   'Wien',
#   'September',
#   'Anfang',
#   'Sitzung',
#   'Anwesend',
#   'Mitglied',
#   'permanent',
#   'Commission',
#   'Herr',
#   'Fligely',
#   'Bruhns',
#   'Forsch',
#   'Commissare',
#   'Herr',
#   'Barozzi',
#   'Ganahl',
#   'Perrier',
#   'Plantamour',
#   'Saget',
#   'Thöt',
#   'Tinter',
#   'Vecchi',
#   'Präsident',
#   'Herr',
#   'Fligely',
#   'Präsident',
#   'eröffnen',
#   'Sitzung',
#   'sprechen',
#   'Bedauern',
#   'permanent',
#   'Commission',
#   'Mitglied',
#   'anwesend',
#   'wodurch',
#   'beschlussfähig',
#   'verlesen',
#   'Schreiben',
#   'Herrn',
#   'Baeyer',
#   'Heidelberg',
#   'erkranken',
#   'Schreiben',
#   'Herrn',
#   'Bauernfeind',
#   'Bad',
#   'ge-',
#   'brauchen',
#   'Schreiben',
#   'Herrn',
#   'Hirsch',
#   'ebenfalls',
#   'Krankheit',
#   'reisen',
#   'ausfahren',
#   'Schreiben',
#   'Herrn',
#   'Bauernfeind',
#   'Einladung',
#   'Name',
#   'Königl',
#   'Bayerische',
#   'Minister',
#   'Dr.',
#   'nächst',
#   'München',
#   'abhalten',
#   'Präsident',
#   'begrüsst',
#   'anwesend',
#   'Herr',
#   'sprechen',
#   'Freude',
#   'Name',
#   'französisch',
#   'Regierung',
#   'Herr',
#   'Oberst',
#   'Saget',
#   'Capitain',
#   'Perrier',
#   'Yvon',
#   'Villarceau',
#   'gegenwärtig',
#   'Versammlung',
#   'theilt',
#   'fern',
#   'letzt',
#   'Versammlung',
#   'permanente',
#   'Commission',
#   'Verlust',
#   'zweier',
#   'Mitglied',
#   'Herr',
#   'Delaunay',
#   'Kaiser',
#   'Tod',
#   'be-',
#   'einig',
#   'Mittheilungen',
#   'Stand',
#   'Gradmessungs-Arbeiten',
#   'ver-',
#   'schiedenen',
#   'Land',
#   'setzen',
#   'Präsident',
#   'nächst',
#   'Sitzung',
#   'September',
#   'ersuchen',
#   'anwesend',
#   'Herr',
#   'alsdann',
#   'Stand',
#   'Arbeit',
#   'mein',
#   'Land',
#   'Bericht',
#   'erstatten',
#   'Schluss',
#   'Sitzung',
#   'Minute',
#   'Sitzung',
#   'permanent',
#   'Commission',
#   'Verhandelt',
#   'Wien',
#   'September',
#   'Anfang',
#   'Sitzung',
#   'Minute',
#   'Anwesend',
#   'Mitglied',
#   'permanent',
#   'Commission',
#   'Herr',
#   'Fligely',
#   'Bruhns',
#   'Forsch',
#   'Ibanez',
#   'Vecchi',
#   'Commissare',
#   'Herr',
#   'Barogei',
#   'Ganahl',
#   'Perrier',
#   'Peter',
#   'Plantamour',
#   'sagen',
#   'Thöt',
#   'Herr',
#   'Oberst',
#   'Dobner',
#   'Chef',
#   'militär-geographischen',
#   'Institut',
#   'Präsident',
#   'Herr',
#   'Fligely',
#   'Protokoll',
#   'vorig',
#   'Sitzung',
#   'verlesen',
#   'genehmigen',
#   'anwesend',
#   'Mitglied',
#   'vertheilt',
#   'Publikation',
#   'militär-',
#   'geographisch',
#   'Institut',
#   'astronomisch-geodätischen',
#   'Arbeit',
#   'binden',
#   'fern',
#   'französisch',
#   'Commissaren',
#   'Uebersichtskarte',
#   'Triangulation',
#   'Algier',
#   'Präsident',
#   'verkünden',
#   'permanente',
#   'Commission',
#   'fähig',
#   'telegraphischem',
#   'Weg',
#   'Stimme',
#   'abwesend',
#   'Mitglied',
#   'Ergänzung',
#   'permanent',
#   'Commission',
#   'einholen',
#   'stellen',
#   'Majorität',
#   'Herr',
#   'Vecchi',
#   'wählen',
#   'beschließen',
#   'stellen',
#   'Generalconferenz',
#   'lassen',
#   'verkünden',
#   'Herrn',
#   'Vecchi',
#   'Mitglied',
#   'permanent',
#   'Commission',
#   'Herr',
#   'Vecchi',
#   'nehmen',
#   'Wahl',
#   'danken',
#   'Vorbehalt',
#   'nachträglich',
#   'Genehmigung',
#   'Regierung',
#   'Präsident',
#   'verkünden',
#   'perma-',
#   'nente',
#   'Commission',
#   'Statuten',
#   'beschlussfähig',
#   'Herr',
#   'Vecchi',
#   'giebt',
#   'Fortschritt',
#   'Gradmessungs-',
#   'arbeiten',
#   'Italien',
#   'wovon',
#   'kurz',
#   'Auszug',
#   'Protokoll',
#   'anhängen',
#   'Bericht',
#   'Generalbericht',
#   'erscheinen',
#   'Appendix',
#   'Herr',
#   'Capitain',
#   'Perrier',
#   'sprechen',
#   'Triangulation',
#   'Algier',
#   'Ost',
#   'West',
#   'fast',
#   'Grad',
#   'Kilometer',
#   'umfasst',
#   'Nivellirung',
#   'verbinden',
#   'interessante',
#   'Resultat',
#   'ergeben',
#   'Auszug',
#   'Vortrag',
#   'Protokoll',
#   'beigeben',
#   'Detail',
#   'General-',
#   'bericht',
#   'erscheinen',
#   'Appendix',
#   'Herr',
#   'Yvon',
#   'Villarceau',
#   'halten',
#   'Vortrag',
#   'Bestimmung',
#   'Declination',
#   'Stern',
#   'Gradmessung',
#   'verwenden',
#   'Auszug',
#   'ebenfalls',
#   'Protokoll',
#   'Appendix',
#   'III',
#   'geben',
#   'Schluss',
#   'Sitzung',
#   'Minute',
#   'Sitzung',
#   'permanent',
#   'Commission',
#   'Verhandelt',
#   'Wien',
#   'September',
#   'Anfang',
#   'Sitzung',
#   'Minute',
#   'Anwesend',
#   'Herr',
#   'Fligely',
#   'Bruhms',
#   'Forsch',
#   'Ibanez',
#   'Vecchi',
#   'Präsident',
#   'Herr',
#   'Fhigely',
#   'Commission',
#   'beschliesst',
#   'stimmen',
#   'Erklärung',
#   'Herrn',
#   'Professor',
#   'Leipzig',
#   'betreffen',
#   'Kritik',
#   'Herrn',
#   'Weingarten',
#   'Protokoll',
#   'Sitzung',
#   'permanent',
#   'Commission',
#   'September',
#   'Pro-',
#   'aufnehmen',
#   'sämmtlichen',
#   'Mitglied',
#   'permanent',
#   'Commission',
#   'übersenden',
#   'Herr',
#   'Baeyer',
#   'Antrag',
#   'stellen',
#   'permanente',
#   'Commission',
#   'mögen',
#   'gestatten',
#   'mein',
#   'Sitzung',
#   'vertreten',
#   'lassen',
#   'können',
#   'permanente',
#   'Commission',
#   'erklären',
#   'Antrag',
#   'berathen',
#   'Statuten',
#   'vor-',
#   'sehen',
#   'Antrag',
#   'nächst',
#   'Conferenz',
#   'berathen',
#   'Antrag',
#   'Herrn',
#   'Baeyer',
#   'permanente',
#   'Commission',
#   'mögen',
#   'Königl',
#   'Preussische',
#   'Ministerium',
#   'geistlich',
#   'Unterrichts-',
#   'heiten',
#   'Schreiben',
#   'Ersuchen',
#   'Centralbureau',
#   'Local',
#   'Ver-',
#   'gleichung',
#   'Basisapparaten',
#   'untereinander',
#   'währen',
#   'richten',
#   'Präsident',
#   'annehmen',
#   'Schriftführer',
#   'beauftragen',
#   'Schreiben',
#   'abfassen',
#   'Schluss',
#   'Sitzung',
#   'Sitzung',
#   'permanent',
#   'Commission',
#   'Verhandelt',
#   'Wien',
#   'September',
#   'Anfang',
#   'Sitzung',
#   'Minute',
#   'Anwesend',
#   'Mitglied',
#   'permanent',
#   'Commission',
#   'Herr',
#   'Fligely',
#   'Bruhns',
#   'Forsch',
#   'Ibanez',
#   'Vecchi',
#   'Commissare',
#   'Herr',
#   'Barogei',
#   'Ganahl',
#   'Perrier',
#   'Peter',
#   'Saget',
#   'Thöt',
#   'Villarcean',
#   'Präsident',
#   'Herr',
#   'Fligely',
#   'Protokoll',
#   'Sitzung',
#   'September',
#   'verlesen',
#   'Bericht',
#   'Herrn',
#   'Baeyer',
#   'Präsident',
#   'Centralbureaus',
#   'Arbeit',
#   'mitgetheilt',
#   'Appendix',
#   'Protokoll',
#   'beifügen',
#   'Herr',
#   'Ibanez',
#   'berichten',
#   'Fortschritt',
#   'Gradmessungs',
#   'Arbeit',
#   'Spanien',
#   'Auszug',
#   'enthalten',
#   'Appendix',
#   'Herr',
#   'Villarceau',
#   'halten',
#   'Vortrag',
#   'Länge',
#   'Breite',
#   'Azimuthe',
#   'Pariser',
#   'Sternwarte',
#   'ausführen',
#   'Localattraction',
#   'Siehe',
#   'Appendix',
#   'Plantamour',
#   'berichten',
#   'Fortschritt',
#   'Arbeit',
#   'Schweiz',
#   'theilt',
#   'Differenz',
#   'Seite',
#   'Präcisions-Nivellements',
#   'vorig',
#   'zeigen',
#   'mehrfach',
#   'Localattraction',
#   'hervorbringen',
#   'betrachten',
#   'vorhanden',
#   'Wiederholung',
#   'Messung',
#   'Ablesungsfehler',
#   'Meter',
#   'zeigen',
#   'Polygonalschluss',
#   'innerhalb',
#   'zulässig',
#   'Fehlergrenze',
#   'Herr',
#   'Forsch',
#   'Mittheilung',
#   'Fortschritt',
#   'Gradmessungs-',
#   'Arbeit',
#   'Russland',
#   'Siehe',
#   'Appendix',
#   'VII',
#   'Herr',
#   'Peter',
#   'berichten',
#   'Altonaer',
#   'Sternwarte',
#   'ausgeführt',
#   'Ar-',
#   'beiten',
#   'Siehe',
#   'Appendix',
#   'VII',
#   'Herr',
#   'Barozzi',
#   'sprechen',
#   'Arbeit',
#   'Rumänien',
#   'verschieden',
#   'Dreieckspunkten',
#   'Pyramide',
#   'Signal',
#   'errichten',
#   'ausführlich',
#   'Bericht',
#   'Generalbericht',
#   'einliefern',
#   'Herr',
#   'erwähnen',
#   'Mittheilung',
#   'österreichisch',
#   'Arbeit',
#   'beson-',
#   'ders',
#   'Verbindung',
#   'italienisch',
#   'Dreieck',
#   'Basismessung',
#   'Eger',
#   'Präcisions-Nivellements',
#   'Wien',
#   'Triest',
#   'Laibach',
#   'Pragerhof',
#   'astronomisch',
#   'Ortsbestimmung',
#   'Corfu',
#   'Herr',
#   'Bruhns',
#   'schlagen',
#   'Sitzung',
#   'Berathung',
#   'Programm',
#   'Generalconferenz',
#   'nächst',
#   'verlesen',
#   'Programm',
#   'letzt',
#   'Generalconferenz',
#   'vorliegen',
#   'Schluss',
#   'Sitzung',
#   'Sitzung',
#   'permanent',
#   'Commission',
#   'Verhandelt',
#   'Wien',
#   'September',
#   'Anfang',
#   'Sitzung',
#   'Minute',
#   'Anwesend',
#   'Mitglied',
#   'permanent',
#   'Commission',
#   'Herr',
#   'Fligely',
#   'Bruhns',
#   'Forsch',
#   'Ibanez',
#   'Vecchi',
#   'Commissare',
#   'Herr',
#   'Perrier',
#   'Peter',
#   'Saget',
#   'Thöt',
#   'Villarcean',
#   'Präsident',
#   'Herr',
#   'Fligely',
#   'Protokoll',
#   'Sitzung',
#   'September',
#   'vorlesen',
#   'genehmigen',
#   'Herr',
#   'Perrier',
#   'halten',
#   'Vortrag',
#   'Triangulation',
#   'Corsica',
#   'wo-',
#   'Verbindung',
#   'Italien',
#   'Frankreich',
#   'ermöglichen',
#   'vorläufig',
#   'Rechnung',
#   'geodätisch',
#   'astronomisch',
#   'Position',
#   'Diffe-',
#   'renzen',
#   'zeigen',
#   'Localattraction',
#   'weise',
#   'halten',
#   'Messung',
#   'Richtung',
#   'Dreieckspunkten',
#   'Dreieckspunkten',
#   'Corsica',
#   'hoffen',
#   'interessante',
#   'Resultat',
#   'ergeben',
#   'Herr',
#   'Villarceau',
#   'einig',
#   'Bemerkung',
#   'Centrirung',
#   'Station',
#   'Herr',
#   'Fligely',
#   'stellen',
#   'Antrag',
#   'permanente',
#   'Commission',
#   'mögen',
#   'Wunsch',
#   'aussprechen',
#   'astronomisch',
#   'Bestimmung',
#   'Länge',
#   'breiten',
#   'Azimuthes',
#   'hauptsächlichsten',
#   'geodätisch',
#   'Punkt',
#   'französisch',
#   'Netz',
#   'aufnehmen',
#   'mögen',
#   'Proposition',
#   'einstimmig',
#   'annehmen',
#   'Herr',
#   'Thöt',
#   'stellen',
#   'Antrag',
#   'Generalconferenz',
#   'Königl',
#   'ungarisch',
#   'Regierung',
#   'gestellt',
#   'Antrag',
#   'wiederholen',
#   'mögen',
#   'Wechsel',
#   'Ministerium',
#   'beachten',
#   'scheinen',
#   'permanente',
#   'Commission',
#   'beschliesst',
#   'Herr',
#   'Fligely',
#   'Name',
#   'Antrag',
#   'Kenntniss',
#   'Regierung',
#   'bringen',
#   'Discussion',
#   'Aufstellung',
#   'Programm',
#   'nächst',
#   'General-',
#   'betheiligen',
#   'Herr',
#   'Bruhns',
#   'Forsch',
#   'Herr',
#   'Ibanez',
#   'Veccht',
#   'Perrier',
#   'beschließen',
#   'Programm',
#   'folgend',
#   'Fassung',
#   'geben',
#   'Entwurf',
#   'Programm',
#   'Europäische',
#   'Gradmessung',
#   'Ueber',
#   'astronomische',
#   'Bestimmung',
#   'Arbeit',
#   'Ueber',
#   'Position',
#   'benutzen',
#   'Fixsterne',
#   'Ueber',
#   'Beobachtung',
#   'Bestimmung',
#   'Intensität',
#   'Schwere',
#   'Ueber',
#   'Maassvergleichungen',
#   'Ueber',
#   'Messung',
#   'Grundlinien',
#   'Ueber',
#   'geodätisch',
#   'Richtungsbeobachtungen',
#   'Ueber',
#   'Nivellements',
#   'Ueber',
#   'Publikation',
#   'Gradmessungs',
#   'Arbeit',
#   'Antrag',
#   'permanent',
#   'Commission',
#   'einzeln',
#   'punkten',
#   'Circular',
#   'Herr',
#   'Commissare',
#   'ersuchen',
#   'einzelne',
#   'punkten',
#   'Discussion',
#   'anmelden',
#   'permanente',
#   'Commission',
#   'Hülfe',
#   'eingehend',
#   'Material',
#   'definitive',
#   'Pro-',
#   'gramm',
#   'aufstellen',
#   'anwesend',
#   'Mitglied',
#   'folgend',
#   'Frage',
#   'Berathung',
#   'empfehlen',
#   'Punkt',
#   'Herrn',
#   'empfehlen',
#   'innerhalb',
#   'Bestimmung',
#   'astronomisch',
#   'geodätisch',
#   'Coordinaten',
#   'ten',
#   'nahe',
#   'sowohl',
#   'Länge',
#   'breiten',
#   'entfernen',
#   'empfehlen',
#   'Gegend',
#   'astronomisch',
#   'Bestimmung',
#   'zahlreich',
#   'Gruppe',
#   'Bestimmung',
#   'vervollständigen',
#   'Bestimmung',
#   'Figur',
#   'Seite',
#   'ermitteln',
#   'Gegenstand',
#   'hören',
#   'nothwendig',
#   'Programm',
#   'Europäische',
#   'Grad-',
#   'messung',
#   'wünschen',
#   'Gang',
#   'Arbeit',
#   'stören',
#   'beschäftigen',
#   'möglichst',
#   'kurz',
#   'astronomisch',
#   'geodä-',
#   'tischen',
#   'Datum',
#   'vereinigen',
#   'obig',
#   'vorschlagen',
#   'enthalten',
#   'Sache',
#   'deutsch',
#   'Gruppe',
#   'bezeichnen',
#   'obig',
#   'Bedingung',
#   'erfüllen',
#   'voraussetzen',
#   'zahlreich',
#   'astronomisch',
#   'Bestimmung',
#   'deutsch',
#   'Boden',
#   'liegen',
#   'Punkt',
#   'Herrn',
#   'Villarceau',
#   'Appendix',
#   'III',
#   'gegeben',
#   'Methode',
#   'Punkt',
#   'Herrn',
#   'Bruhns',
#   'vortheilhafter',
#   'Reise',
#   'klein',
#   'pendeln',
#   'fest',
#   'Schneiden',
#   'anwenden',
#   'anstatt',
#   'gegenwärtig',
#   'Reversions-',
#   'pendel',
#   'Schneiden',
#   'Herrn',
#   'Peter',
#   'gefunden',
#   'Differenz',
#   '.Bessel',
#   'schen',
#   'Schumacher',
#   'schen',
#   'Aenderung',
#   'Schwerkraft',
#   'deuten',
#   'Punkt',
#   'Basisapparate',
#   'Punkt',
#   'Herrn',
#   'Perrier',
#   'vortheilhaft',
#   'Okular',
#   'Fernröhre',
#   'Mikrometer',
#   'Faden',
#   'anwenden',
#   'Herrn',
#   'Villarceau',
#   'Be-',
#   'obachtungen',
#   'Tagbeobachtungen',
#   'vortheilhafter',
#   'Punkt',
#   'Herrn',
#   'Bruhns',
#   'Art',
#   'mittler',
#   'Höhe',
#   'Meer',
#   'bestimmen',
#   'Punkt',
#   'Zusammenstellung',
#   'Literatur',
#   'Arbeit',
#   'Europäische',
#   'Gradmessung',
#   'wünschenswerth',
#   'Zusammenstellung',
#   'Coordinaten',
#   'Hauptdreieckspunkte',
#   'erlangen',
#   'astronomisch',
#   'nivellitischen',
#   'Resultat',
#   'Herr',
#   'Fligely',
#   'österreichisch',
#   'Arbeit',
#   'europäisch',
#   'Gradmessung',
#   'Mittheilung',
#   'Herr',
#   'Oppolser',
#   'Palisa',
#   'Tinter',
#   'Längen-',
#   'differenzen',
#   'vollenden',
#   'Längendifferenz',
#   'Ausführung',
#   'beginnen',
#   'Azimuth',
#   'vollenden',
#   'Präsident',
#   'anwesend',
#   'Commissaren',
#   'Gegenwart',
#   'Theilnahme',
#   'danken',
#   'schliesst',
#   'Sitzung',
#   'Sitzung',
#   'permanent',
#   'Commission',
#   'Verhandelt',
#   'Wien',
#   'September',
#   'Anfang',
#   'Sitzung',
#   'Abends',
#   'Anwesend',
#   'Herr',
#   'Fligely',
#   'Bruhns',
#   'Forsch',
#   'Ibanez',
#   'Vecchi',
#   'Präsident',
#   'Herr',
#   'Fligely',
#   'Protokoll',
#   'vorig',
#   'Sitzung',
#   'verlesen',
#   'genehmigen',
#   'Sitzung',
#   'September',
#   'beschlossen',
#   'Schreiben',
#   'Königl',
#   'Preussische',
#   'Ministerium',
#   'geistlich',
#   'Unterrichts-',
#   'Medicinal',
#   'Angelegenheit',
#   'vorlegen',
#   'folgend',
#   'formen',
#   'genehmigen',
#   'Königl',
#   'Preussische',
#   'Ministerium',
#   'geistlich',
#   'Unterrichts-',
#   'Medicinal-Angelegenheiten',
#   'Berlin',
#   'hoch',
#   'Königl',
#   'Ministerium',
#   'Excellenz',
#   'Herr',
#   'General-',
#   'lieutenant',
#   'Dr.',
#   'Baeyer',
#   'permanente',
#   'Commission',
#   'Europäische',
#   'Gradmessung',
#   'berichten',
#   'selbigem',
#   'gewünscht',
#   'Ausführung',
#   'Arbeit',
#   'Centralbureaus',
#   'bereitwilligst',
#   'währen',
#   'sprechen',
#   'permanente',
#   'Commission',
#   'mein',
#   'innig',
#   'Vergleichung',
#   'verschieden',
#   'Basisapparate',
#   'Herr',
#   'Generallieutenant',
#   'Dr.',
#   'Baeyer',
#   'mehrfach',
#   'bemühen',
#   'passend',
#   'Local',
#   'erhalten',
#   'gelingen',
#   'Folge',
#   'An-',
#   'wenden',
#   'permanente',
#   'Commission',
#   'Königl',
#   'Mini-',
#   'bitten',
#   'Centralbureau',
#   'europäisch',
#   'Gradmessung',
#   'Stand',
#   'setzen',
#   'Vergleichung',
#   'Basisapparate',
#   'Messstangen',
#   'ausfahren',
#   'unterzeichnen',
#   'Commission',
#   'Interesse',
#   'Europäische',
#   'Gradmessung',
#   'Gewährung',
#   'bitten',
#   'entgegen',
#   'sehen',
#   'wagen',
#   'verharren',
#   'grösster',
#   'permanente',
#   'Commission',
#   'Europäische',
#   'Gradmessung',
#   'gez',
#   'Fligely',
#   'Bruhns',
#   'Präsident',
#   'Schriftführer',
#   'Herr',
#   'Fligely',
#   'Mittheilung',
#   'Verhandlung',
#   'verschieden',
#   'Regierung',
#   'Behörde',
#   'Königl',
#   'Regierung',
#   'Errichtung',
#   'Pegel',
#   'Helgoland',
#   'einwenden',
#   'sehen',
#   'ver-',
#   'Kosten',
#   'tragen',
#   'Ferner',
#   'Mangel',
#   'Mittel',
#   'Ausführung',
#   'Gradmessung',
#   'denken',
#   'Venedig',
#   'Behörde',
#   'November',
#   'Pegel',
#   'errichten',
#   'Behörde',
#   'Neapel',
#   'Herrn',
#   'Leitung',
#   'Errichtung',
#   'Pegel',
#   'Schritt',
#   'thun',
#   'Herr',
#   'Veecchi',
#   'theilt',
#   'Brindisi',
#   'Pegel',
#   'errichten',
#   'Ort',
#   'nächst',
#   'Conferenz',
#   'München',
#   'Dresden',
#   'Berlin',
#   'vorschlagen',
#   'Commission',
#   'entscheiden',
#   'Stimme',
#   'Dresden',
#   'Einladung',
#   'Königl',
#   'Bairische',
#   'Minister',
#   'Herrn',
#   'Dr.',
#   'München',
#   'sprechen',
#   'Commission',
#   'mein',
#   'Geschäftsordnung',
#   'nächst',
#   'all',
#   'vorig',
#   'Conferenz',
#   'beibehalten',
#   'Herr',
#   'Fligely',
#   'theilt',
#   'Theil',
#   'Abtheilung',
#   'Königl',
#   'Preussischen',
#   'Landestriangulation',
#   'bekommen',
#   'Triangulation',
#   'Basismessung',
#   'Schleswig-Holstein',
#   'erschienen',
#   'Theil',
#   'Gradmessung',
#   'enthalten',
#   'beschließen',
#   'Centralbureau',
#   'ersuchen',
#   'Publikation',
#   'Exemplar',
#   'neu',
#   'ernannt',
#   'Commissare',
#   'Ausführung',
#   'Herrn',
#   'Bruhns',
#   'beauftragen',
#   'drucken',
#   'gegenwärtig',
#   'Protokoll',
#   'Manuscript',
#   'deutsch',
#   'französisch',
#   'Sprache',
#   'beschließen',
#   'Herr',
#   'Bruhms',
#   'beauftragen',
#   'Centralbureau',
#   'Ausführung',
#   'ersuchen',
#   'gemein',
#   'Conferenz',
#   'beschließen',
#   'Haupt-',
#   'Material',
#   'europäisch',
#   'vorhanden',
#   'senden',
#   'Schluss',
#   'Sitzung',
#   'Sitzung',
#   'permanent',
#   'Commission',
#   'Verhandelt',
#   'Wien',
#   'September',
#   'Anfang',
#   'Sitzung',
#   'Protokoll',
#   'vorig',
#   'Sitzung',
#   'verlesen',
#   'genehmigen',
#   'Herr',
#   'Vecchi',
#   'theilt',
#   'Herr',
#   'Donati',
#   'Bedauern',
#   'Wissenschaft',
#   'September',
#   'plötzlich',
#   'sterben',
#   'Herr',
#   'Fligely',
#   'gebeten',
#   'K.K.',
#   'Oesterreichischen',
#   'Regierung',
#   'Commission',
#   'abstatten',
#   'Schluss',
#   'Sitzung',
#   'Minute',
#   'Vollzogen',
#   'Wien',
#   'September',
#   'August',
#   'Fligely',
#   'Dr.',
#   'Bruhns',
#   'Präsident',
#   'Schriftführer',
#   'Ibaneg',
#   'Vecchi',
#   'Forsch',
#   'Ausgabe',
#   'Inhalt',
#   'Schreiben',
#   'Herrn',
#   'Professor',
#   'Wittstein',
#   'Erledigung',
#   'finden',
#   'Appendix',
#   'LAVORI',
#   'MISURA',
#   'DEL',
#   'GRADO',
#   'EUROPEO',
#   'primo',
#   'calcolo',
#   'compensazione',
#   'trigonometrica',
#   'che',
#   'Stato',
#   'Maggiore',
#   'ora',
#   'Istituto',
#   'Topografico',
#   'presentato',
#   'alla',
#   'Commissione',
#   'come',
#   'alla',
#   'misura',
#   'del',
#   'Grado',
#   'europeo',
#   'stato',
#   'quello',
#   'Sicilia',
#   'Esso',
#   'alla',
#   'rete',
#   'ordine',
#   'quale',
#   'dalla',
#   'base',
#   'Catania',
#   'estende',
#   'sud',
#   'sino',
#   'Capopassaro',
#   'est',
#   'sino',
#   'mare',
#   'ovest',
#   'sino',
#   'punti',
#   'nord',
#   'sino',
#   'punti',
#   'Angelo',
#   'Patti',
#   'compensazione',
#   'eseguita',
#   'tre',
#   'parti',
#   'cioe',
#   'una',
#   'che',
#   'abbraccia',
#   'rete',
#   'dis-',
#   'tesa',
#   'tra',
#   'base',
#   'lato',
#   'offre',
#   'condizioni',
#   'due',
#   'altre',
#   'parti',
#   'condizioni',
#   'quali',
#   'due',
#   'della',
#   'rimanente',
#   'rete',
#   'quadrilatero',
#   'secondo',
#   'lavoro',
#   'del',
#   'eseguito',
#   'dal',
#   'Corpo',
#   'stesso',
#   'della',
#   'rete',
#   'che',
#   'parte',
#   'dalla',
#   'base',
#   'Foggia',
#   'estende',
#   'sud',
#   'sino',
#   'punti',
#   'Biccari',
#   'Ascoli',
#   'est',
#   'sino',
#   'punti',
#   'Torrepietre',
#   'ovest',
#   'sino',
#   'punti',
#   'Tremiti',
#   'nord',
#   'sino',
#   'punti',
#   'Lissa',
#   'Lagosta',
#   'qui',
#   'che',
#   'nel',
#   'quadrilatero',
#   'che',
#   'centro',
#   'Pelagosa',
#   'osservazioni',
#   'furono',
#   'nel',
#   'austriaci',
#   'italiani',
#   'cosi',
#   'nei',
#   'calcoli',
#   'italiani',
#   'furono',
#   'adoperati',
#   'solo',
#   'dati',
#   'con-',
#   'sol',
#   'rete',
#   'quadrilatero',
#   'compensazione',
#   'calcoli',
#   'austriaci',
#   'due',
#   'reti',
#   'con',
#   'Esso',
#   'calcolo',
#   'eseguito',
#   'nel',
#   'modo',
#   'indicato',
#   'condizioni',
#   'presentato',
#   'alla',
#   'Commissione',
#   'internazionale',
#   'nella',
#   'riunione',
#   'Vienna',
#   'nel',
#   'ultimo',
#   'lavoro',
#   'compensazione',
#   'all',
#   'della',
#   'per',
#   'misura',
#   'del',
#   'Grado',
#   'Berlino',
#   'quello',
#   'rete',
#   'sulla',
#   'base',
#   'del',
#   'Orati',
#   'rete',
#   'estende',
#   'sud',
#   'sino',
#   'punti',
#   'est',
#   'sino',
#   'punti',
#   'Trionto',
#   'ovest',
#   'sino',
#   'punti',
#   'nord',
#   'sino',
#   'punti',
#   'Alpi',
#   'Nocara',
#   'Tal',
#   'compensazione',
#   'che',
#   'offre',
#   'compiuta',
#   'nel',
#   'corso',
#   'del',
#   'alla',
#   'fine',
#   'dello',
#   'stesso',
#   'anno',
#   'alla',
#   'Commis-',
#   'internazionale',
#   'calcolo',
#   'compensazione',
#   'abbraccia',
#   'rete',
#   'che',
#   'dalla',
#   'base',
#   'del',
#   'Orati',
#   'parte',
#   'sulla',
#   'Calabria',
#   'parte',
#   'sul',
#   'mare',
#   'sud',
#   'punti',
#   'Patti',
#   'ovest',
#   'Lipari',
#   'Stromboli',
#   'est',
#   'punti',
#   'nord',
#   'punti',
#   'Trionto',
#   'Tal',
#   'lavoro',
#   'quale',
#   'offre',
#   'condizioni',
#   'sul',
#   'punto',
#   'alla',
#   'Commissione',
#   'inter-',
#   'unito',
#   'sulla',
#   'misura',
#   'della',
#   'base',
#   'del',
#   'Crati',
#   'nuovi',
#   'dellen',
#   'spranghe',
#   'tra',
#   'loro',
#   'con',
#   'tesa',
#   'qui',
#   'utile',
#   'che',
#   'per',
#   'completare',
#   'compensazione',
#   'della',
#   'zona',
#   'trigono-',
#   'meridiana',
#   'tra',
#   'Capopassaro',
#   'Lissa',
#   'solo',
#   'ultimo',
#   'calcolo',
#   'quello',
#   'che',
#   'abbraccia',
#   'rete',
#   'trä',
#   'punti',
#   'Alpi',
#   'Nocara',
#   'sud',
#   'trä',
#   'punti',
#   'Biccari',
#   'Ascoli',
#   'Torrepietre',
#   'nord',
#   'tra',
#   'punti',
#   'est',
#   'punti',
#   'ovest',
#   'Tal',
#   'calcolo',
#   'poträ',
#   'essere',
#   'nel',
#   'corso',
#   'dell',
#   'anno',
#   'sono',
#   'lavori',
#   'relativi',
#   'alla',
#   'trigonometrica',
#   'quali',
#   'furono',
#   'sono',
#   'alla',
#   'Commissione',
#   'internationale',
#   'alcuni',
#   'quali',
#   'dati',
#   'per',
#   'del',
#   'Sigr',
#   'General',
#   'Vecchi',
#   'Direttore',
#   'dell',
#   'Istituto',
#   'Topografico',
#   'Presidente',
#   'della',
#   'Commissione',
#   'italiana',
#   'Grado',
#   'europeo',
#   'intorno',
#   'questi',
#   'ultimi',
#   'lavori',
#   'che',
#   'nel',
#   'ebbe',
#   'luogo',
#   'per',
#   'prima',
#   'sull',
#   'Bessel',
#   'Ertel',
#   'furono',
#   'della',
#   'tesa',
#   'all',
#   'apparato',
#   'valore',
#   'dellen',
#   'parti',
#   'ebbe',
#   'luogo',
#   'dellen',
#   'spranghe',
#   'con',
#   'tesa',
#   'quella',
#   'dellen',
#   'spranghe',
#   'tra',
#   'loro',
#   'che',
#   'gli',
#   'elementi',
#   'tali',
#   'furono',
#   'ritenuti',
#   'nella',
#   'base',
#   'Foggia',
#   'misurata',
#   'nel',
#   'quella',
#   'Napoli',
#   'misurata',
#   'nel',
#   'nell',
#   'altra',
#   'Catania',
#   'cui',
#   'misura',
#   'ebbe',
#   'luogo',
#   'nel',
#   'che',
#   'nelle',
#   'basi',
#   'come',
#   'quella',
#   'del',
#   'Crati',
#   'misurate',
#   'negli',
#   'anni',
#   'furono',
#   'ritenuti',
#   'gli',
#   'elementi',
#   'che',
#   'quando',
#   'Commissione',
#   'internationale',
#   'una',
#   'misura',
#   'Berlino',
#   'queste',
#   'alla',
#   'tesa',
#   'Bessel',
#   'Commissione',
#   'italiana',
#   'dal',
#   'Spano',
#   'una',
#   'tesa',
#   'quale',
#   'nel',
#   'paragonata',
#   'dal',
#   'Corpo',
#   'Stato',
#   'Maggiore',
#   'quella',
#   'Ertel',
#   'apparato',
#   'Berlino',
#   'tale',
#   'tesa',
#   'quella',
#   'Bessel',
#   'nel',
#   'Napoli',
#   'nuovamente',
#   'paragonata',
#   'alla',
#   'tesa',
#   'Ertel',
#   'LAVORI',
#   'MISURA',
#   'DEL',
#   'GRADO',
#   'EUROPEO',
#   'Lavori',
#   'Geodetici',
#   'nel',
#   'sotto',
#   'direzione',
#   'del',
#   'Tente',
#   'misura',
#   'della',
#   'base',
#   'del',
#   'Crati',
#   'osservazioni',
#   'angolari',
#   'pel',
#   'rattacco',
#   'essa',
#   'reti',
#   'basi',
#   'Foggia',
#   'Catania',
#   'trian-',
#   'sino',
#   'che',
#   'per',
#   'Est',
#   'Roma',
#   'nei',
#   'seguenti',
#   'anni',
#   'sotto',
#   'medesima',
#   'direzione',
#   'seguenti',
#   'lavori',
#   'cioe',
#   'nel',
#   'Dai',
#   'Sigri',
#   'Vita',
#   'Maggia',
#   'dal',
#   'Tente',
#   'Mottura',
#   'dall',
#   'Sigr',
#   'misura',
#   'una',
#   'base',
#   'presso',
#   'Lecce',
#   'della',
#   'lunghezza',
#   'piü',
#   'quale',
#   'rete',
#   'parallela',
#   'che',
#   'Capo',
#   'rattacco',
#   'colla',
#   'triangolazione',
#   'fatta',
#   'dall',
#   'Austria',
#   'dell',
#   'Albania',
#   'nelle',
#   'Isole',
#   'Dal',
#   'Capno',
#   'Maggia',
#   'eseguirono',
#   'nuovamente',
#   'stazioni',
#   'Stromboli',
#   'Lipari',
#   'Sta',
#   'St.',
#   'Angelo',
#   'Patti',
#   'Castania',
#   'dal',
#   'Tte',
#   'Mottura',
#   'quella',
#   'onde',
#   'triangolazione',
#   'quella',
#   'poligoni',
#   'com-',
#   'Dai',
#   'operatori',
#   'dai',
#   'Sigri',
#   'Capni',
#   'Del',
#   'Giudice',
#   'Tente',
#   'Ingegneri',
#   'Atri',
#   'triangolazione',
#   'dellen',
#   'Terre',
#   'sino',
#   'con',
#   'quella',
#   'fatta',
#   'nel',
#   'Nel',
#   'Dai',
#   'Sigri',
#   'Capni',
#   'Maggia',
#   'dal',
#   'Tte',
#   'Simi',
#   'furono',
#   'fatte',
#   'stazioni',
#   'Lecce',
#   'Serrano',
#   'pel',
#   'rattacco',
#   'dellen',
#   'reti',
#   'colle',
#   'Mar',
#   'per',
#   'parte',
#   'dell',
#   'Austria',
#   'due',
#   'stazioni',
#   'Fand',
#   'dal',
#   'Capitano',
#   'Sterneck',
#   'dal',
#   'Tente',
#   'Steffan',
#   'Come',
#   'vede',
#   'dal',
#   'grafico',
#   'rat-',
#   'tacco',
#   'piü',
#   'controlli',
#   'lato',
#   'viene',
#   'condizioni',
#   'dalla',
#   'vieina',
#   'base',
#   'operatori',
#   'dai',
#   'Sigri',
#   'Capno',
#   'Del',
#   'Giudice',
#   'Tente',
#   'Atri',
#   'stanno',
#   'ora',
#   'stazioni',
#   'che',
#   'nelle',
#   'provincie',
#   'Napoli',
#   'zona',
#   'che',
#   'nell',
#   'grafico',
#   'con',
#   'Maggiore',
#   'General',
#   'Direttore',
#   'dell',
#   'Istituto',
#   'militare',
#   'Veechi',
#   'Appendix',
#   'capitaine',
#   'Perrier',
#   'fait',
#   'connaitre',
#   'abord',
#   'les',
#   'travaux',
#   'Algerie',
#   'par',
#   'les',
#   'officiers',
#   'Etat-major',
#   'frangais',
#   'Une',
#   'premiöre',
#   'base',
#   'metres',
#   'environ',
#   'longueur',
#   'mesurde',
#   'dans',
#   'plaine',
#   'entre',
#   'elle',
#   'servi',
#   'cöt',
#   'depart',
#   'pour',
#   'calcul',
#   'cöt&s',
#   'une',
#   'chaine',
#   'qui',
#   'Tunisie',
#   'celles',
#   'Maroc',
#   'qui',
#   'constitue',
#   'arc',
#   'kilomötres',
#   'longueur',
#   'Deux',
#   'autres',
#   'hases',
#   'ont',
#   'mesurdes',
#   'vers',
#   'les',
#   'cette',
#   'chaine',
#   'aux',
#   'Böne',
#   'Oran',
#   'Les',
#   'altitudes',
#   'sommets',
#   'geodesiques',
#   'ont',
#   'moyen',
#   'resultats',
#   'fournis',
#   'par',
#   'observation',
#   'distances',
#   'zenithales',
#   'partant',
#   'niveau',
#   'moyen',
#   'mer',
#   'Alger',
#   'Une',
#   'chaine',
#   'meridienne',
#   'dirigde',
#   'suivant',
#   'meridien',
#   'Biskra',
#   'vient',
#   'ötre',
#   'terminde',
#   'jusqu',
#   'hauteur',
#   'dont',
#   'lit',
#   'parait',
#   'ötre',
#   'mötres',
#   'niveau',
#   'mer',
#   'Une',
#   'deuxiöme',
#   'chaine',
#   'meridienne',
#   'dirigde',
#   'peu',
#   'pres',
#   'suivant',
#   'möridien',
#   'Paris',
#   'commencee',
#   'assez',
#   'loin',
#   'vers',
#   'sud',
#   'mais',
#   'elle',
#   'est',
#   'par',
#   'suite',
#   'guerre',
#   'Enfin',
#   'observations',
#   'astronomiques',
#   'latitude',
#   'azimut',
#   'ont',
#   'Alger',
#   'Oran',
#   'ces',
#   'deux',
#   'points',
#   'aussi',
#   'mesur',
#   'longitude',
#   'par',
#   'observation',
#   'lunaires',
#   'mais',
#   'seulement',
#   'pour',
#   'avoir',
#   'une',
#   'valeur',
#   'cet',
#   '16-',
#   'ment',
#   'attendant',
#   'une',
#   'determination',
#   'plus',
#   'exacte',
#   'par',
#   'capitaine',
#   'Perrier',
#   'ensuite',
#   'sur',
#   'relier',
#   'jour',
#   'reseau',
#   'geodesique',
#   'Algerie',
#   'avec',
#   'celui',
#   'rösulte',
#   'effet',
#   'une',
#   'reconnaissance',
#   'sur',
#   'les',
#   'cötes',
#   'Algerie',
#   'regard',
#   'cötes',
#   'Espagne',
#   'que',
#   'les',
#   'points',
#   'Espagne',
#   'Algerie',
#   'forment',
#   'immense',
#   'qui',
#   'pourra',
#   'servir',
#   'reseau',
#   'jonction',
#   'entre',
#   'les',
#   'deux',
#   'Europe',
#   'tout',
#   'moins',
#   'une',
#   'premiere',
#   'bien',
#   'reconnaissance',
#   'pour',
#   'cette',
#   'grande',
#   'operation',
#   'internationale',
#   'Ainsi',
#   'Parc',
#   'möridien',
#   'frangais',
#   'dejä',
#   'vers',
#   'nord',
#   'jusqu',
#   'aux',
#   'Shetland',
#   'pourra',
#   's’&tendre',
#   'bientöt',
#   'travers',
#   'Espagne',
#   'Möditerrande',
#   'jusqu',
#   'Algerie',
#   'suivant',
#   'les',
#   'chemin',
#   'vers',
#   'sud',
#   'continuera',
#   'dans',
#   'les',
#   'Sahara',
#   'ainsi',
#   'une',
#   'amplitude',
#   'moins',
#   'Sur',
#   'proposition',
#   'Bureau',
#   'Longitudes',
#   'Etat-major',
#   'francais',
#   'serait',
#   'utile',
#   'partie',
#   'grand',
#   'arc',
#   'capitaine',
#   'Perrier',
#   'une',
#   'nouvelle',
#   'dötermination',
#   'Meridienne',
#   'France',
#   'les',
#   'op6rations',
#   'ont',
#   'ete',
#   'deja',
#   'entre',
#   'chaine',
#   'parallöle',
#   'moyen',
#   'degrös',
#   'les',
#   'instruments',
#   'reiteration',
#   'ont',
#   'remplac',
#   'les',
#   'cercles',
#   'aux',
#   'signaux',
#   'bois',
#   'pierres',
#   'signaux',
#   'une',
#   'vis',
#   'place',
#   'lunette',
#   'permet',
#   'considerablement',
#   'les',
#   'erreurs',
#   'pointe',
#   'nouvelle',
#   'triangulation',
#   'espagnole',
#   'nouvelle',
#   'France',
#   'par',
#   'cöte',
#   'commun',
#   'Dans',
#   'une',
#   'deuxieme',
#   'seance',
#   'capitaine',
#   'Perrier',
#   'attention',
#   'röunion',
#   'sur',
#   'les',
#   'travaux',
#   'geodesiques',
#   'qui',
#   'ont',
#   'servi',
#   'fondement',
#   'Carte',
#   'cette',
#   'ile',
#   'Appendix',
#   'DETERMINATION',
#   'PAR',
#   'YVON',
#   'Les',
#   'grandes',
#   'discordances',
#   'divers',
#   'catalogues',
#   'declinaisons',
#   'toiles',
#   'methodes',
#   'leur',
#   'determination',
#   'pendant',
#   'les',
#   'progres',
#   'ceux',
#   'nos',
#   'connaissances',
#   'sur',
#   'figure',
#   'Terre',
#   'que',
#   'les',
#   'döclinaisons',
#   'haut',
#   'degrö',
#   'certitude',
#   'Nous',
#   'eroyons',
#   'que',
#   'rösultat',
#   'pourra',
#   'ötre',
#   'atteint',
#   'ayant',
#   'recours',
#   'nouvelles',
#   'methodes',
#   'dans',
#   'cette',
#   'pensde',
#   'nous',
#   'nous',
#   'attention',
#   'sur',
#   'projet',
#   'que',
#   'nous',
#   'avons',
#   'communique',
#   'Bureau',
#   'Longitudes',
#   'dans',
#   'seance',
#   'fevrier',
#   'dans',
#   'Memoire',
#   'pr&sente',
#   'mars',
#   'möme',
#   'annee',
#   'Commission',
#   'Observatoire',
#   'Paris',
#   'source',
#   'difficultes',
#   'que',
#   'rencontre',
#   'nous',
#   'parait',
#   'ötre',
#   'dans',
#   'une',
#   'th&orie',
#   'röfractions',
#   'qui',
#   'suppose',
#   'horizontal',
#   'les',
#   'air',
#   'möme',
#   'cette',
#   'condition',
#   'que',
#   'ment',
#   'une',
#   'autre',
#   'cause',
#   'est',
#   'dans',
#   'toiles',
#   'qui',
#   'permet',
#   'pas',
#   'rögion',
#   'que',
#   'devrait',
#   'moins',
#   'lorsque',
#   'les',
#   'distances',
#   'zenithales',
#   'toiles',
#   'certaines',
#   'limites',
#   'emploi',
#   'excellent',
#   'instrument',
#   'meridien',
#   'Rigaud',
#   'installation',
#   'cet',
#   'instrument',
#   'sous',
#   'une',
#   'simpel',
#   'toile',
#   'nous',
#   'avons',
#   'nous',
#   'assurer',
#   'que',
#   'les',
#   'distances',
#   'zenithales',
#   'moindres',
#   'que',
#   'peuvent',
#   'tre',
#   'encore',
#   'que',
#   'r&sultat',
#   'moyen',
#   'ces',
#   'observations',
#   'celles',
#   'etoiles',
#   'observees',
#   'discussion',
#   'observations',
#   'faites',
#   'dans',
#   'les',
#   'meilleures',
#   'conditions',
#   'atmo-',
#   'nous',
#   'permis',
#   'fixer',
#   'relativement',
#   'aux',
#   'latitudes',
#   'une',
#   'limite',
#   'erreur',
#   'moyenne',
#   'une',
#   'observation',
#   'isolde',
#   'erreur',
#   'dont',
#   'source',
#   'est',
#   'aux',
#   'im-',
#   'instrument',
#   'sens',
#   'vision',
#   'Cette',
#   'limite',
#   'differe',
#   'peu',
#   'Elle',
#   'comprend',
#   'les',
#   'erreurs',
#   'point',
#   'les',
#   'erreurs',
#   'points',
#   'les',
#   'erreurs',
#   'imparfaitement',
#   'divisions',
#   'valeurs',
#   'vis',
#   'mieroscopes',
#   'les',
#   'erreurs',
#   'röfractions',
#   'celles',
#   'flexion',
#   'verticale',
#   'Lunette',
#   'les',
#   'erreurs',
#   'döclinaisons',
#   '6toiles',
#   'Nous',
#   'pas',
#   'les',
#   'erreurs',
#   'observation',
#   'division',
#   'cercle',
#   'attendu',
#   'les',
#   'par',
#   'retournement',
#   'lorsque',
#   'position',
#   'relative',
#   'cercle',
#   'Lunette',
#   'observateur',
#   'est',
#   'dans',
#   'les',
#   'deux',
#   'positions',
#   'Instrument',
#   'Nous',
#   'ainsi',
#   'pouvoir',
#   'que',
#   'erreur',
#   'effective',
#   'une',
#   'latitude',
#   'beaucoup',
#   'superieure',
#   'est',
#   'pour',
#   'plus',
#   'grande',
#   'partie',
#   'aux',
#   'in-',
#   'atmospheriques',
#   'bien',
#   'que',
#   'erreur',
#   'declinaisons',
#   'toiles',
#   'soit',
#   'loin',
#   'ötre',
#   'Notre',
#   'conviction',
#   'cet',
#   'gard',
#   'est',
#   'telle',
#   'que',
#   'nous',
#   'pas',
#   'que',
#   'les',
#   'tentatives',
#   'pour',
#   'precision',
#   'instrumental',
#   'aujourd',
#   'hui',
#   'aucun',
#   'resultat',
#   'bien',
#   'utile',
#   'que',
#   'les',
#   'astronomes',
#   'doivent',
#   'porter',
#   'toute',
#   'leur',
#   'attention',
#   'sur',
#   'les',
#   'moyens',
#   'aux',
#   'effets',
#   'presque',
#   'toujours',
#   'refractions',
#   'veuille',
#   'bien',
#   'nous',
#   'permettre',
#   'moins',
#   'pour',
#   'fixer',
#   'les',
#   'les',
#   'distances',
#   'zönithales',
#   'jusqu',
#   'comme',
#   'bien',
#   'que',
#   'Association',
#   'geodesique',
#   'internationale',
#   'ait',
#   'cru',
#   'devoir',
#   'limiter',
#   'ces',
#   'distances',
#   'Nous',
#   'allons',
#   'ex-',
#   'poser',
#   'comment',
#   'serait',
#   'possible',
#   'sans',
#   'telles',
#   'limites',
#   'obtenir',
#   'les',
#   'toiles',
#   'fondamentales',
#   'fournir',
#   'exactitude',
#   'rösultats',
#   'ob-',
#   'cette',
#   'exactitude',
#   'Une',
#   'telle',
#   'möthode',
#   'une',
#   'sur',
#   'les',
#   'möthodes',
#   'usage',
#   'puisque',
#   'celles-ci',
#   'sont',
#   'autre',
#   'contröle',
#   'celui',
#   'qui',
#   'r&sulte',
#   'comparaison',
#   'divers',
#   'catalogues',
#   'Yon',
#   'combien',
#   'contröle',
#   'est',
#   'puisque',
#   'comparaison',
#   'dont',
#   'agit',
#   'aboutit',
#   'constater',
#   'discordances',
#   'telles',
#   'que',
#   'peut',
#   'sür',
#   'certaines',
#   'etoiles',
#   'fondamentales',
#   'm&me',
#   'pres',
#   'Pour',
#   'rendre',
#   'plus',
#   'nouvelle',
#   'möthode',
#   'nous',
#   'ferons',
#   'pour',
#   'moment',
#   'provenant',
#   'une',
#   'dans',
#   'voisinage',
#   'pöle',
#   'austral',
#   'terres',
#   'Supposons',
#   'observateur',
#   'exerce',
#   'soit',
#   'muni',
#   'cercle',
#   'vertical',
#   'analogue',
#   'celui',
#   'mais',
#   'dimensions',
#   'beaucoup',
#   'moindres',
#   'cercle',
#   'par',
#   'exemple',
#   'lunette',
#   'distance',
#   'focale',
#   'ailleurs',
#   'bien',
#   'observateur',
#   'ira',
#   'ötablir',
#   'dans',
#   'voisinage',
#   'cerele',
#   'polaire',
#   'par',
#   'cette',
#   'latitude',
#   'pourra',
#   'observer',
#   'polaire',
#   'ses',
#   'passages',
#   'superieur',
#   'sans',
#   'depasser',
#   'limite',
#   'distance',
#   'zenithale',
#   'cette',
#   'maniere',
#   'position',
#   'pöle',
#   'par',
#   'suite',
#   'les',
#   'distances-polaires-nord',
#   'toiles',
#   'lors',
#   'leur',
#   'passage',
#   'superieur',
#   'entre',
#   'pöle',
#   'son',
#   'zenith',
#   'une',
#   'part',
#   'puis',
#   'jusqu',
#   'distance',
#   'zenithale',
#   'cöt',
#   'sud',
#   'travail',
#   'fait',
#   'observateur',
#   'vers',
#   'sud',
#   'plus',
#   'premiere',
#   'station',
#   'observant',
#   'une',
#   'zöne',
#   'toiles',
#   'dans',
#   'cette',
#   'premiere',
#   'station',
#   'les',
#   'plus',
#   'australes',
#   'pourra',
#   'fixer',
#   'les',
#   'distances',
#   'polaires',
#   'une',
#   'nouvelle',
#   'zöne',
#   'sans',
#   'depasser',
#   'limite',
#   'pour',
#   'les',
#   'distances',
#   'zenithales',
#   'est',
#   'clair',
#   'que',
#   'observateur',
#   'aura',
#   'plus',
#   'faire',
#   'deux',
#   'nouvelles',
#   'stations',
#   'pour',
#   'atteindre',
#   'cerele',
#   'polaire',
#   'les',
#   'observations',
#   'toutes',
#   'les',
#   'dont',
#   'les',
#   'distances-polaires-nord',
#   'ainsi',
#   'determindes',
#   'Mai',
#   'dans',
#   'cette',
#   'station',
#   'position',
#   'pöle',
#   'austral',
#   'obtiendra',
#   'directement',
#   'les',
#   'distances',
#   'maintenant',
#   'contröle',
#   'auquel',
#   'les',
#   'r&sultats',
#   'seront',
#   'faudra',
#   'que',
#   'les',
#   'distances',
#   'polaires',
#   'nord',
#   'sud',
#   'tant',
#   'donnent',
#   'une',
#   'somme',
#   'Sans',
#   'doute',
#   'accord',
#   'sera',
#   'pas',
#   'mais',
#   'pourra',
#   'examiner',
#   'accord',
#   'est',
#   'non',
#   'Dans',
#   'cas',
#   'plus',
#   'celui',
#   'une',
#   'discordance',
#   'aurait',
#   'appliquer',
#   'une',
#   'correction',
#   'constante',
#   'refraction',
#   'introduire',
#   'dans',
#   'expression',
#   'flexion',
#   'Lunette',
#   'terme',
#   'doubeln',
#   'distance',
#   'zenithale',
#   'terme',
#   'que',
#   'pas',
#   'les',
#   'moyens',
#   'directement',
#   'nous',
#   'est',
#   'impossibel',
#   'nous',
#   'jusqu',
#   'quel',
#   'point',
#   'polaire',
#   'exdcution',
#   'projet',
#   'qui',
#   'vient',
#   'ötre',
#   'sans',
#   'doute',
#   'les',
#   'observateurs',
#   'qui',
#   'dans',
#   'les',
#   'terres',
#   'australes',
#   'pour',
#   'observer',
#   'passage',
#   'nous',
#   'ments',
#   'nous',
#   'allons',
#   'examiner',
#   'cas',
#   'devrait',
#   'renoncer',
#   'etablir',
#   'plus',
#   'pres',
#   'que',
#   'faudrait',
#   'alors',
#   'systeme',
#   'observations',
#   'effectuer',
#   'dans',
#   'sphöre',
#   'austral',
#   'station',
#   'extröme',
#   'serait',
#   'plus',
#   'possible',
#   'döterminer',
#   'sition',
#   'pöle',
#   'austral',
#   'puisque',
#   'les',
#   'passages',
#   'circompolaires',
#   'auraient',
#   'lieu',
#   'par',
#   'distances',
#   'zenithales',
#   'limite',
#   'difficult',
#   'aux',
#   'observations',
#   'distances',
#   'zönithales',
#   'celles',
#   'digressions',
#   'azimutales',
#   'circompolaires',
#   'observees',
#   'dans',
#   'station',
#   'comprise',
#   'entre',
#   'station',
#   'l’&quateur',
#   'est',
#   'facile',
#   'rendre',
#   'compte',
#   'transporte',
#   'par',
#   'pensee',
#   'l’&quateur',
#   'möme',
#   'effet',
#   'somme',
#   'digressions',
#   'orientale',
#   'occidentale',
#   'une',
#   'toile',
#   'sera',
#   'pröcisement',
#   'doubeln',
#   'polaire',
#   'sans',
#   'dire',
#   'que',
#   'propose',
#   'pas',
#   'effectuer',
#   'sous',
#   'genre',
#   'observations',
#   'est',
#   'afın',
#   'avoir',
#   'pas',
#   'lutter',
#   'contre',
#   'les',
#   'refractions',
#   'qui',
#   'peuvent',
#   'trös',
#   'horizon',
#   'rösulte',
#   'calculs',
#   'qui',
#   'peuvent',
#   'trouver',
#   'leur',
#   'place',
#   'ici',
#   'que',
#   'combinaison',
#   'digressions',
#   'azimutales',
#   'dans',
#   'une',
#   'station',
#   'voisine',
#   'avec',
#   'celle',
#   'distances',
#   'zenithales',
#   'observees',
#   'dans',
#   'm&me',
#   'station',
#   'dans',
#   'station',
#   'plus',
#   'meridionale',
#   'permet',
#   'determiner',
#   'position',
#   'pöle',
#   'austral',
#   'seule',
#   'que',
#   'pourrait',
#   'presenter',
#   'est',
#   'relative',
#   'instrument',
#   'qui',
#   'elle',
#   'pas',
#   'convenablement',
#   'dans',
#   'les',
#   'resultats',
#   'une',
#   'erreur',
#   'pouvant',
#   'peu',
#   'celle',
#   'dötermination',
#   'cette',
#   'constante',
#   'instrumental',
#   'ailleurs',
#   'trös',
#   'peu',
#   'chose',
#   'prös',
#   'retournement',
#   'entre',
#   'les',
#   'observations',
#   'qui',
#   'celles',
#   'qui',
#   'suivent',
#   'moment',
#   'plus',
#   'grande',
#   'sont',
#   'les',
#   'bases',
#   'que',
#   'nous',
#   'astronomes',
#   'dans',
#   'pensde',
#   'que',
#   'travaux',
#   'qui',
#   'ex&cutent',
#   'dans',
#   'les',
#   'observatoires',
#   'pour',
#   'dötermination',
#   'declinaisons',
#   'fondamentales',
#   'peuvent',
#   'quelque',
#   'r&soudre',
#   'question',
#   'avec',
#   'degrö',
#   'ex-',
#   'devenu',
#   'notre',
#   'poque',
#   'Appendix',
#   'Bericht',
#   'Geodätische',
#   'Institut',
#   'resp',
#   'Central-',
#   'Europäische',
#   'Gradmessung',
#   'Geodätische',
#   'Institut',
#   'bestand',
#   'Sectionen',
#   'Sectionschef',
#   'definitiv',
#   'besetzen',
#   'Leitung',
#   'Arbeit',
#   'astronomisch',
#   'Section',
#   'Herr',
#   'Director',
#   'Bruhns',
#   'Leipzig',
#   'bereitwilligst',
#   'übernehmen',
#   'Weise',
#   'Fortgang',
#   'Arbeit',
#   'aufs',
#   'sorgen',
#   'letzt',
#   'Nivellementsarbeiten',
#   'Verbindung',
#   'registrirenden',
#   'Pegel',
#   'dergestalt',
#   'stellen',
#   'Ar-',
#   'beiten',
#   'nothwendig',
#   'erscheinen',
#   'pro',
#   'Vorschlag',
#   'bringen',
#   'Herbst',
#   'Seite',
#   'Ministerium',
#   'Herr',
#   'Finanzminister',
#   'stellen',
#   'bewilligen',
#   'wolle',
#   'definitiv',
#   'besetzen',
#   'vornehm',
#   'wobei',
#   'Herr',
#   'Director',
#   'Bruhms',
#   'unterstützen',
#   'Dr.',
#   'Leitung',
#   'arbeiten',
#   'stellen',
#   'Vorschlag',
#   'bringen',
#   'Januar',
#   'Herrn',
#   'Dr.',
#   'Albrecht',
#   'provisorisch',
#   'besetzen',
#   'Folge',
#   'Herr',
#   'Dr.',
#   'Albrecht',
#   'reihen',
#   'preussischen',
#   'Commissare',
#   'melden',
#   'hiermit',
#   'Herr',
#   'Finanzminister',
#   'stellen',
#   'genehmigen',
#   'Professor',
#   'Börsch',
#   'Juli',
#   'Sectionschef',
#   'anstellen',
#   'Maassvergleichungen',
#   'Beobachtung',
#   'Herr',
#   'Professor',
#   'Voit',
#   'Professor',
#   'Sadebeck',
#   'Dr.',
#   'Schur',
#   'März',
#   'Juni',
#   'hoch',
#   'nieder',
#   'Temperatur',
#   'Be-',
#   'stimmung',
#   'Ausdehnungscoefficienten',
#   'verschieden',
#   'ausge-',
#   'führen',
#   'Rechnung',
#   'Widerspruch',
#   'führen',
#   'Ursache',
#   'hinlänglich',
#   'aufklären',
#   'einzig',
#   'sicher',
#   'Resultat',
#   'Vergleichung',
#   'Stab',
#   'Bessel',
#   'schen',
#   'Toise',
#   'nachstehend',
#   'Verzeichniss',
#   'angiebt',
#   'Länge',
#   'Toise',
#   'Nummer',
#   'Meter',
#   'München',
#   'Geod',
#   'Inst',
#   'unversucht',
#   'lassen',
#   'Ursache',
#   'erwähnen',
#   'Wider-',
#   'entdecken',
#   'Professor',
#   'Sadebeck',
#   'Dr.',
#   'Albrecht',
#   'Comparator',
#   'auseinander',
#   'nehmen',
#   'Theile',
#   'Sorgfältigste',
#   'untersuchen',
#   'Untersuchung',
#   'Lothablenkungen',
#   'harzen',
#   'bekanntlich',
#   'Brocken',
#   'Vergleichung',
#   'astronomisch',
#   'geodätisch',
#   'Bestimmung',
#   'unbeträchtliche',
#   'Lothablenkung',
#   'zeigen',
#   'Herr',
#   'Dr.',
#   'Albrecht',
#   'laufen',
#   'Sommer',
#   'südlich',
#   'Brocken',
#   'gelegen',
#   'Station',
#   'Mühlhausen',
#   'Tettenborn',
#   'Hohegeiss',
#   'nördlich',
#   'gelegen',
#   'Station',
#   'Ilsenburg',
#   'Asse',
#   'Wolfenbüttel',
#   'Polhöhen',
#   'messen',
#   'vorläufig',
#   'berechnen',
#   'glauben',
#   'definitiv',
#   'Resultat',
#   'einzeln',
#   'punkten',
#   'höchstens',
#   'Bogensecunde',
#   'ändern',
#   'vorläufig',
#   'erhalten',
#   'Resultat',
#   'Süden',
#   'Norden',
#   'gehen',
#   'folgend',
#   'Tabelle',
#   'enthalten',
#   'Höhe',
#   'astronomisch',
#   'Geodätische',
#   'Meer',
#   'breiten',
#   'breiten',
#   'Ablenkung',
#   'Inselsberg',
#   'Fuss',
#   'Seeberg',
#   'Mühlhausen',
#   'Tettenborn',
#   'Hohegeiss',
#   'Brocken',
#   'Ilsenburg',
#   'Fallstein',
#   'Asse',
#   'Appendix',
#   'Bericht',
#   'Herrn',
#   'Ibanez',
#   'commencement',
#   'mois',
#   'honneur',
#   'envoyer',
#   'Son',
#   'Excel-',
#   'Bureau',
#   'central',
#   'rapport',
#   'fait',
#   'publier',
#   'sur',
#   'les',
#   'travaux',
#   'geodösiques',
#   'ordre',
#   'ex&cutes',
#   'par',
#   'Institut',
#   'g6ographique',
#   'Espagne',
#   'depuis',
#   'con-',
#   'ference',
#   'Vienne',
#   'aurai',
#   'done',
#   'entretenir',
#   'Commission',
#   'permanente',
#   'que',
#   'travaux',
#   'faits',
#   'dans',
#   'les',
#   'six',
#   'mois',
#   'derniers',
#   'Quatre',
#   'stations',
#   'qui',
#   'chaine',
#   'ont',
#   'faites',
#   'qui',
#   'pour',
#   'publication',
#   'cette',
#   'importante',
#   'chaine',
#   'moyen',
#   'laquelle',
#   'nous',
#   'avons',
#   'obtenu',
#   'premiöre',
#   'jonction',
#   'entre',
#   'r&seau',
#   'France',
#   'celui',
#   'Espagne',
#   'par',
#   'les',
#   'trois',
#   'cöt6s',
#   'communs',
#   'triangle',
#   'Une',
#   'cinquieme',
#   'station',
#   'faite',
#   'sur',
#   'plus',
#   'chaine',
#   'qui',
#   'procure',
#   'avec',
#   'sommet',
#   'avait',
#   'stationne',
#   'auparavant',
#   'seconde',
#   'jonction',
#   'nos',
#   'travaux',
#   'avec',
#   'ceux',
#   'France',
#   'Enfin',
#   'par',
#   'les',
#   'observations',
#   'faites',
#   'aux',
#   'sommets',
#   'ancienne',
#   'France',
#   'Espagne',
#   'dont',
#   'mesure',
#   'röcemment',
#   'par',
#   'les',
#   'Gouvernements',
#   'deux',
#   'pays',
#   'observations',
#   'latitude',
#   'azimuts',
#   'ont',
#   'lieu',
#   'maintenant',
#   'sur',
#   'cöte',
#   'Oc&an',
#   'stationne',
#   'Merino',
#   'Observatoire',
#   'Madrid',
#   'Les',
#   'nivellements',
#   'pröcision',
#   'ont',
#   'cette',
#   'annde',
#   'avec',
#   'une',
#   'grande',
#   'ligne',
#   'Madrid',
#   'port',
#   'Santander',
#   'ayant',
#   'une',
#   'longueur',
#   'plus',
#   'kilometres',
#   'commencee',
#   'mois',
#   'avec',
#   'plusieurs',
#   'instruments',
#   'elle',
#   'sera',
#   'doubeln',
#   'avant',
#   'fin',
#   'Elle',
#   'avec',
#   'celle',
#   'Madrid',
#   'Alicante',
#   'une',
#   'grande',
#   'ligne',
#   'continue',
#   'mille',
#   'kilomötres',
#   'environ',
#   'doubeln',
#   'qui',
#   'traversera',
#   'Pöninsule',
#   'Oc&an',
#   'Möditerrande',
#   'Appendix',
#   'DETERMINATION',
#   'PAR',
#   'PARIS',
#   'PAR',
#   'YVON',
#   'Association',
#   'internationale',
#   'nous',
#   'fait',
#   'honneur',
#   'ses',
#   'recueils',
#   'quelques',
#   'rösultats',
#   'obtenus',
#   'par',
#   'Observatoire',
#   'Paris',
#   'Bureau',
#   'Longitudes',
#   'qui',
#   'toujours',
#   'fait',
#   'hommage',
#   'Association',
#   'exemplaires',
#   'ses',
#   'sur',
#   'cette',
#   'serait',
#   'heureux',
#   'que',
#   'les',
#   'rösultats',
#   'astronomiques',
#   'qui',
#   'sont',
#   'comme',
#   'par',
#   'passe',
#   'ötre',
#   'dans',
#   'les',
#   'recueils',
#   'Comptes-rendus',
#   'Association',
#   'g&odesique',
#   'internationale',
#   'Les',
#   'points',
#   'les',
#   'determinations',
#   'astronomiques',
#   'ont',
#   'sont',
#   'les',
#   'suivants',
#   'Dunkergue',
#   'Brest',
#   'Strasbourg',
#   'Talmay',
#   'Rodez',
#   'Carcassonne',
#   'Lyon',
#   'St.',
#   'Martin-du-Tertre',
#   'derniöre',
#   'ces',
#   'stations',
#   'faite',
#   'bien',
#   'que',
#   'depuis',
#   'lors',
#   'ait',
#   'fait',
#   'trois',
#   'reprises',
#   'differentes',
#   'les',
#   'nouvelles',
#   'seulement',
#   'ötre',
#   'circonstances',
#   'divers',
#   'nature',
#   'sont',
#   'auquel',
#   'Bureau',
#   'Longitudes',
#   'cependant',
#   'pas',
#   'entiörement',
#   'perdu',
#   'pour',
#   'science',
#   'puisqu',
#   'partie',
#   'recherches',
#   'dont',
#   'lui',
#   'reste',
#   'entretenir',
#   'Commission',
#   'sur',
#   'les',
#   'attractions',
#   'locales',
#   'par',
#   'Observatoire',
#   'Paris',
#   'discuter',
#   'les',
#   'que',
#   'pre-',
#   'reconnu',
#   'apres',
#   'France',
#   'les',
#   'coordonnees',
#   'geodesiques',
#   'ques',
#   'apres',
#   'quelgues',
#   'impossibilit',
#   'obtenir',
#   'accord',
#   'satisfaisant',
#   'moyen',
#   'corrections',
#   'convenables',
#   'donnees',
#   'depart',
#   'dans',
#   'calcul',
#   'coordonnees',
#   'geodesiques',
#   'Les',
#   'resultats',
#   'fournis',
#   'par',
#   'nos',
#   'observations',
#   'astronomiques',
#   'pouvant',
#   'ätre',
#   'que',
#   'erreurs',
#   'tout-A-fait',
#   'cause',
#   'discordances',
#   'devait',
#   'plus',
#   'ötre',
#   'que',
#   'dans',
#   'les',
#   'nos',
#   'operations',
#   'dans',
#   'existence',
#   'attractions',
#   'locales',
#   'Bien',
#   'motifs',
#   'avaient',
#   'fait',
#   'exactitude',
#   'operations',
#   'fondamentales',
#   'Delambre',
#   'mais',
#   'pas',
#   'erreurs',
#   'fallait',
#   'mettre',
#   'celles',
#   'dont',
#   'elles',
#   'sont',
#   'peuvent',
#   'encore',
#   'ätre',
#   'Deux',
#   'pour',
#   'obtenir',
#   'resultat',
#   'recommencer',
#   'les',
#   'trian-',
#   'dans',
#   'meilleures',
#   'conditions',
#   'bien',
#   'faire',
#   'part',
#   'cela',
#   'possible',
#   'attractions',
#   'locales',
#   'dernier',
#   'moyen',
#   'seul',
#   'immödiatement',
#   'accessible',
#   'pas',
#   'agissait',
#   'rien',
#   'moins',
#   'que',
#   'etablir',
#   'une',
#   'th&orie',
#   'vrai',
#   'par',
#   'Laplace',
#   'mais',
#   'par',
#   'son',
#   'dans',
#   'qui',
#   'obtenir',
#   'rösultat',
#   'pas',
#   'plus',
#   'Les',
#   'tentatives',
#   'autres',
#   'illuster',
#   'pas',
#   'Mai',
#   'dois',
#   'dire',
#   'que',
#   'plus',
#   'heureux',
#   'est',
#   'gräce',
#   'emploi',
#   'mode',
#   'trop',
#   'nos',
#   'jours',
#   'par',
#   'les',
#   'les',
#   'faits',
#   'ils',
#   'ont',
#   'appris',
#   'Ayant',
#   'compar',
#   'courbe',
#   'discordances',
#   'entre',
#   'les',
#   'longitudes',
#   'astronomiques',
#   'g&odesiques',
#   'dans',
#   'partie',
#   'Meridienne',
#   'France',
#   'comprise',
#   'entre',
#   'Paris',
#   'Carcassonne',
#   'avec',
#   'courbe',
#   'discordances',
#   'azimutales',
#   'ces',
#   'deux',
#   'courbes',
#   'suis',
#   'immediatement',
#   'cette',
#   'question',
#   'une',
#   'relation',
#   'n&cessaire',
#   'entre',
#   'les',
#   'effets',
#   'attractions',
#   'locales',
#   'sur',
#   'les',
#   'longitudes',
#   'sur',
#   'les',
#   'azimuts',
#   'question',
#   'est',
#   'ainsi',
#   'que',
#   'par',
#   'simpel',
#   'triangle',
#   'immödiatement',
#   'ötablir',
#   'premier',
#   'th&or&me',
#   'sur',
#   'les',
#   'attractions',
#   'locales',
#   'dont',
#   'theor&me',
#   'Laplace',
#   'trouve',
#   'tre',
#   'cas',
#   'tres',
#   'particulier',
#   'theoreme',
#   'dans',
#   'General-Bericht',
#   'Cependant',
#   'lors',
#   'conference',
#   'qui',
#   'lieu',
#   'question',
#   'attractions',
#   'locales',
#   'sans',
#   'ait',
#   'fait',
#   'mention',
#   'nouveau',
#   'theoreme',
#   'Mr.',
#   'Schering',
#   'annonce',
#   'existence',
#   'plusieurs',
#   'thöor&mes',
#   'non',
#   'encore',
#   'publies',
#   'pour',
#   'fait',
#   'non',
#   'publication',
#   'discussion',
#   'une',
#   'autre',
#   'Sept',
#   'ans',
#   'sont',
#   'sans',
#   'que',
#   'question',
#   'ait',
#   'reprise',
#   'par',
#   'Association',
#   'geodesique',
#   'inter-',
#   'national',
#   'attend',
#   'toujours',
#   'publication',
#   'par',
#   'Mr.',
#   'Schering',
#   'Mai',
#   'notre',
#   'cöte',
#   'theorie',
#   'attractions',
#   'locales',
#   'fait',
#   'quelques',
#   'progres',
#   'que',
#   'exposer',
#   'attendu',
#   'que',
#   'les',
#   'rösultats',
#   'mes',
#   'recherches',
#   'ont',
#   'dans',
#   'qui',
#   'ont',
#   'tous',
#   '1’Association',
#   'une',
#   'application',
#   'faite',
#   'parallöle',
#   'Paris',
#   'partie',
#   'meridienne',
#   'comprise',
#   'entre',
#   'Paris',
#   'Carcassonne',
#   'rösultat',
#   'est',
#   'Bien',
#   'existe',
#   'une',
#   'discordance',
#   'plus',
#   'entre',
#   'les',
#   'longitudes',
#   'astronomiques',
#   'geodesiques',
#   'Strasbourg',
#   'pres',
#   'quantit6',
#   'comme',
#   'erreur',
#   'azimut',
#   'chaine',
#   'Strasbourg',
#   'contraire',
#   'partie',
#   'occidentale',
#   'parallöle',
#   'Paris',
#   'ainsi',
#   'que',
#   'les',
# ...
#   'einzeln',
#   'Staat',
#   'Entgegennahme',
#   'Vor-',
#   'schläge',
#   'geodätisch',
#   'Section',
#   'Frage',
#   'Herr',
#   'Bruhns',
#   'verlesen',
#   'Brief',
#   'Herrn',
#   'Seidel',
#   'bedauern',
#   'Abhandlung',
#   'Ueber',
#   'Berechnung',
#   'wahrschein-',
#   'lichsten',
#   'Werthe',
#   'Unbekannte',
#   'Bedingungsgleichungen',
#   'bestehen',
#   'Vertheilung',
#   'anwesend',
#   'Commissare',
#   'übersenden',
#   'Vertheilung',
#   'vor-',
#   'nehmen',
#   'Herr',
#   'Ganahl',
#   'berichten',
#   'einig',
#   'astronomische',
#   'trigonome-',
#   'trischen',
#   'nivellitischen',
#   'Arbeit',
#   'österreichisch-ungarischen',
#   'Monarchie',
#   'Meile',
#   'nivellirt',
#   'Meile',
#   'nächst',
#   'Aussicht',
#   'nehmen',
#   'Herr',
#   'Tinter',
#   'theilt',
#   'Kremsmünster',
#   'breiten',
#   'Azimuth',
#   'bestimmen',
#   'Herr',
#   'besprechen',
#   'Vervollständigung',
#   'Fortsetzung',
#   'trigonome-',
#   'trischen',
#   'Netz',
#   'Rumänien',
#   'erwähnen',
#   'Instrument',
#   'Brunner',
#   'Paris',
#   'Messung',
#   'vorhanden',
#   'Herr',
#   'Forsch',
#   'berichten',
#   'Berechnung',
#   'Dreieck',
#   'Umrechnung',
#   'alt',
#   'Triangulationen',
#   'ausgeführt',
#   'Präcisions-Nivellements',
#   'übergiebt',
#   'Bericht',
#   'Herrn',
#   'Pendel-',
#   'bestimmungen',
#   'Herr',
#   'Bruhns',
#   'Mittheilung',
#   'astronomisch',
#   'Arbeit',
#   'König-',
#   'reichen',
#   'Sachsen',
#   'nahe',
#   'vollenden',
#   'Berechnung',
#   'Basismessung',
#   'fertigen',
#   'Publication',
#   'Herr',
#   'nageln',
#   'referirt',
#   'geodätisch',
#   'Arbeit',
#   'Punkt',
#   'messen',
#   'Messung',
#   'Punkt',
#   'Ordnung',
#   'übrig',
#   'Sommer',
#   'vollenden',
#   'Herr',
#   'Hürsch',
#   'berichten',
#   'Triangulationen',
#   'Schweiz',
#   'einig',
#   'nöthig',
#   'binden',
#   'Beobachtung',
#   'nächst',
#   'erscheinen',
#   'Sternwarten',
#   'geodätisch',
#   'Punkt',
#   'astronomisch',
#   'Coordinaten',
#   'Pendellängen',
#   'bestimmen',
#   'Publikation',
#   'stehen',
#   'Nivellement',
#   'Alpe',
#   'Kilometer',
#   'Länge',
#   'Meter',
#   'Grösse',
#   'Centimeter',
#   'Herr',
#   'Ibanez',
#   'theilt',
#   'Arbeit',
#   'Spanien',
#   'mein',
#   'gestört',
#   'Fort-',
#   'gang',
#   'Punkt',
#   'Ordnung',
#   'beobachten',
#   'mehrfach',
#   'astronomische',
#   'Bestimmung',
#   'Herrn',
#   'Merino',
#   'ausführen',
#   'verschieden',
#   'Nivellements',
#   'vollenden',
#   'Mareograph',
#   'Hafen',
#   'Santander',
#   'aufstellen',
#   'Alicante',
#   'Aufstellung',
#   'begriffen',
#   'Berichterstatter',
#   'legen',
#   'fern',
#   'topographische',
#   'karten',
#   'Umgebung',
#   'Madrid',
#   'Maassstabe',
#   'erläutern',
#   'Ausführung',
#   'Herr',
#   'Schoder',
#   'berichten',
#   'Württemberg',
#   'bereitwilligst',
#   'währen',
#   'Aufstellung',
#   'Dreiecksnetzes',
#   'beginnen',
#   'Nivellements',
#   'Kilo-',
#   'meter',
#   'vollenden',
#   'somit',
#   'Berichterstattung',
#   'einzeln',
#   'Staat',
#   'vollenden',
#   'bringen',
#   'Herr',
#   'Hirsch',
#   'Herrn',
#   'Ibanez',
#   'Name',
#   'Verhandlung',
#   'geodätisch',
#   'Section',
#   'Punkt',
#   'Programm',
#   'Vortrag',
#   'Conferenz',
#   'beschliesst',
#   'Punkt',
#   'Herstellung',
#   'mögen',
#   'soviel',
#   'Zweck',
#   'gene',
#   'meist',
#   'Staat',
#   'angenommen',
#   'Conferenz',
#   'Verzug',
#   'einberufen',
#   'wichtig',
#   'wissenschaftlich',
#   'Unternehmen',
#   'nöthige',
#   'inter-',
#   'national',
#   'Organisation',
#   'sicher',
#   'permanente',
#   'Commission',
#   'beauftragen',
#   'gehend',
#   'Schreiben',
#   'französische',
#   'Regierung',
#   'richten',
#   'Ferner',
#   'berichten',
#   'Präsident',
#   'Centralbureaus',
#   'Maassvergleichungen',
#   'fehlen',
#   'beschliesst',
#   'Conferenz',
#   'königlich',
#   'Preussische',
#   'Regierung',
#   'Schreiben',
#   'richten',
#   'bitten',
#   'Generallieutenant',
#   'Dr.',
#   'besonder',
#   'Maassvergleichungen',
#   'brauchbar',
#   'Gebäude',
#   'gewähren',
#   'Betreff',
#   'Frage',
#   'Beschluss',
#   'einstimmig',
#   'annehmen',
#   'Commission',
#   'bestehen',
#   'Herr',
#   'Forsch',
#   'Ganahl',
#   'Ibanez',
#   'Perrier',
#   'Vecchi',
#   'Herrn',
#   'Baeyer',
#   'Seite',
#   'stellen',
#   'Frage',
#   'gut',
#   'Construction',
#   'Basisapparates',
#   'studiren',
#   'permanent',
#   'Commission',
#   'erforderlich',
#   'Vorschlag',
#   'vorlegen',
#   'Herr',
#   'Bruhns',
#   'verkünden',
#   'Punkt',
#   'Tagesordnung',
#   'nächst',
#   'Sitzung',
#   'Montag',
#   'September',
#   'Vormittag',
#   'Wahl',
#   'perma-',
#   'nente',
#   'Commission',
#   'Schluss',
#   'Sitzung',
#   'Minute',
#   'Sitzung',
#   'Verhändelt',
#   'Dresden',
#   'September',
#   'Anfang',
#   'Sitzung',
#   'Minute',
#   'Anwesend',
#   'Herr',
#   'Commissare',
#   'Sitzung',
#   'Aus-',
#   'nahme',
#   'Herrn',
#   'Ganahl',
#   'dringend',
#   'Arbeit',
#   'Ein-',
#   'geladen',
#   'Herr',
#   'Lösche',
#   'Präsident',
#   'Herr',
#   'Forsch',
#   'Schriftführer',
#   'Herr',
#   'Bruhns',
#   'Hirsch',
#   'Protokoll',
#   'vorig',
#   'Sitzung',
#   'verlesen',
#   'genehmigen',
#   'Tagesordnung',
#   'ankündigen',
#   'Wahl',
#   'permanente',
#   'Commission',
#   'Geschäftliches',
#   'Vorschlag',
#   'astronomisch',
#   'geodätisch',
#   'Section',
#   'Berathung',
#   'Frage',
#   'Programm',
#   'Commissare',
#   'anwesend',
#   'schreiben',
#   'Name',
#   'erhalten',
#   'Stimme',
#   'Bruhns',
#   'Faye',
#   'Forsch',
#   'Oppolger',
#   'Veechi',
#   'Ferrero',
#   'Fligely',
#   'Herr',
#   'nageln',
#   'Perrier',
#   'gewählt',
#   'Herr',
#   'Bruhns',
#   'Faye',
#   'Forsch',
#   'Oppolzer',
#   'Vecchi',
#   'danken',
#   'Conferenz',
#   'nehmen',
#   'Wahl',
#   'Genehmigung',
#   'Regie-',
#   'geschäftlich',
#   'Mittheilungen',
#   'liegen',
#   'Brief',
#   'Herrn',
#   'Ministerialrath',
#   'Herr',
#   'worin',
#   'selbiger',
#   'bitten',
#   'Abwesenheit',
#   'dringend',
#   'amtlich',
#   'Geschäft',
#   'entschuldigen',
#   'Herr',
#   'Perrier',
#   'übergiebt',
#   'Memorial',
#   'Depöt',
#   'göneral',
#   'guerre',
#   'Tome',
#   'contenant',
#   'tion',
#   'Algerie',
#   'Memorial',
#   'Depöt',
#   'general',
#   'ete',
#   'wünschen',
#   'Versendung',
#   'genau',
#   'Adresse',
#   'beschließen',
#   'anwesend',
#   'Herr',
#   'Adresse',
#   'genau',
#   'Centralbureau',
#   'erbietet',
#   'genau',
#   'Mittheilung',
#   'Adresse',
#   'resp',
#   'Versendung',
#   'astronomische',
#   'Section',
#   'Herrn',
#   'Oppolzer',
#   'folgend',
#   'berichten',
#   'Beschluß',
#   'Annahme',
#   'Bestimmung',
#   'gedeihen',
#   'erscheinen',
#   'kurz',
#   'momentan',
#   'Gebot',
#   'stehend',
#   'literarisch',
#   'Hilfsmittel',
#   'Frage',
#   'Weise',
#   'Mittheilung',
#   'legen',
#   'demnach',
#   'Section',
#   'Plenum',
#   'Erwartung',
#   'Weise',
#   'tung',
#   'angeregt',
#   'Frage',
#   'erlangen',
#   'ansehen',
#   'Hirsch',
#   'gestellt',
#   'Antrag',
#   'auffordern',
#   'möglich',
#   'Beschleunigung',
#   'Centralbureau',
#   'Mittheilung',
#   'astronomisch',
#   'Arbeit',
#   'ver-',
#   'Land',
#   'Centralbureau',
#   'mögen',
#   'Redaction',
#   'entsprechend',
#   'Publication',
#   'sorgen',
#   'tragen',
#   'Bericht',
#   'Arbeit',
#   'publieirt',
#   'letzter',
#   'fallen',
#   'Reduction',
#   'vollenden',
#   'gedeihen',
#   'fern',
#   'erscheinen',
#   'erwünscht',
#   'angeben',
#   'Aussicht',
#   'genommen',
#   'Arbeit',
#   'Vorschlag',
#   'Excellenz',
#   'Baeyer',
#   'glauben',
#   'Section',
#   'Plenum',
#   'empfehlen',
#   'Einfluss',
#   'Localattraction',
#   'merkbar',
#   'zeigen',
#   'aufmerksam',
#   'früh',
#   'Beschluß',
#   'erproben',
#   'Erfahrung',
#   'Zusatz',
#   'Section',
#   'schlagen',
#   'Plenum',
#   'erklären',
#   'giltig',
#   'wesent-',
#   'liche',
#   'Aenderung',
#   'bieten',
#   'erscheinen',
#   'Hinweis',
#   'Faye',
#   'Benutzung',
#   'Zweck',
#   'Zeitbestimmung',
#   'Mittheilung',
#   'Richtung',
#   'gemacht',
#   'versuchen',
#   'nehmen',
#   'Conferenz',
#   'danken',
#   'Kenntniss',
#   'Erwägung',
#   'Hirsch',
#   'Bruhns',
#   'Schwierigkeit',
#   'vorerst',
#   'Vorschlag',
#   'gegenwärtige',
#   'Operation',
#   'sicher',
#   'erfolgen',
#   'bezeichnen',
#   'Hirsch',
#   'Erledigung',
#   'Frage',
#   'bemerken',
#   'Umstand',
#   'aufmerksam',
#   'Strom',
#   'gleich',
#   'Stärke',
#   'gleich',
#   'merkbar',
#   'verschieden',
#   'entsprechen',
#   'ändern',
#   'Zustand',
#   'Leitung',
#   'auftreten',
#   'Oppolger',
#   'führen',
#   'ähnlich',
#   'Erfahrung',
#   'Erscheinung',
#   'glauben',
#   'Section',
#   'Plenum',
#   'vorschlagen',
#   'Beobachter',
#   'mögen',
#   'möglichst',
#   'zahlreiche',
#   'Beobach-',
#   'Längenbestimmung',
#   'ver-',
#   'Discussion',
#   'Ursache',
#   'Fehlerquelle',
#   'resultirenden',
#   'eliminiren',
#   'nützlich',
#   '9—13',
#   'Punkt',
#   'nahe',
#   'gleichweit',
#   'entfernen',
#   'geodätisch',
#   'Coordinaten',
#   'angeben',
#   'Bestimmung',
#   'Gestalt',
#   'ermitteln',
#   'schädlich',
#   'Einfluß',
#   'Uhr-',
#   'Herr',
#   'Commissare',
#   'mögen',
#   'gung',
#   'eignen',
#   'bringen',
#   'annehmen',
#   'Bezug',
#   'Frage',
#   'gegeben',
#   'Bestimmung',
#   'Position',
#   'Fixsterne',
#   'genügen',
#   'betrachten',
#   'Ansicht',
#   'gelten',
#   'yon',
#   'Neubestimmung',
#   'gegenwärtig',
#   'absehen',
#   'können',
#   'innerhalb',
#   'kurz',
#   'seitens',
#   'Pulkowaer',
#   'Sternwarte',
#   'Veröffentlichung',
#   'Cataloges',
#   'genau',
#   'Position',
#   'Stern',
#   'erwarten',
#   'Ueber',
#   'Frage',
#   'Herrn',
#   'Villarceau',
#   'empfohlen',
#   'Methode',
#   'Appendix',
#   'III',
#   'Bericht',
#   'wienern',
#   'Sitzung',
#   'permanent',
#   'Com-',
#   'mission',
#   'nähern',
#   'erläutern',
#   'ausführbar',
#   'lang',
#   'Herr',
#   'Pillarceau',
#   'legen',
#   'astronomisch',
#   'Section',
#   'Memoire',
#   'Be-',
#   'stimmung',
#   'Declinationen',
#   'erläutern',
#   'nähern',
#   'hinweisen',
#   'Bestimmung',
#   'Deelinationen',
#   'mitteln',
#   'Messung',
#   'Zenithdistanzen',
#   'ungenau',
#   'Kenntniss',
#   'Betrag',
#   'Refraction',
#   'betrachten',
#   'Uebelstande',
#   'ab-',
#   'helfen',
#   'können',
#   'Beobachtung',
#   'Zenithdistanzen',
#   'beschränken',
#   'Gesichtspunkt',
#   'ausgehen',
#   'schlagen',
#   'punkten',
#   'Grad',
#   'nördl',
#   'breiten',
#   'nördlich',
#   'Aequator',
#   'mitteln',
#   'mittler',
#   'Grösse',
#   'Declinationen',
#   'Stern',
#   'innerhalb',
#   'Zone',
#   'Zenithdistanz',
#   'eulminiren',
#   'schärfen',
#   'bestimmen',
#   'fern',
#   'Station',
#   'gemeinschaftlich',
#   'Stern',
#   'Bestimmung',
#   'Station',
#   'verwenden',
#   'Methode',
#   'Beobach-',
#   'tung',
#   'Azimuthes',
#   'Nähe',
#   'grössten',
#   'Digression',
#   'gebrauchen',
#   'Section',
#   'schlagen',
#   'Conferenz',
#   'Anbetracht',
#   'Umstand',
#   'Bestimmung',
#   'Declina-',
#   'tionen',
#   'Stern',
#   'eigentlich',
#   'gebieten',
#   'Gradmessung',
#   'hören',
#   'Memoire',
#   'Herrn',
#   'berichten',
#   'allgemein',
#   'Conferenz',
#   'abdrucken',
#   'Weg',
#   'Kenntniss',
#   'Astronom',
#   'bringen',
#   'Bestimmung',
#   'Declinationen',
#   'Funda-',
#   'beschäftigen',
#   'sprechen',
#   'Section',
#   'Wunsch',
#   'einzeln',
#   'Publica-',
#   'tionen',
#   'unterlassen',
#   'angeben',
#   'Berechnung',
#   'Grund',
#   'gelegt',
#   'Declinationen',
#   'beobachten',
#   'Stern',
#   'soweit',
#   'thunlich',
#   'numerisch',
#   'Werthe',
#   'aufführen',
#   'Herr',
#   'Bärsch',
#   'berichten',
#   'Punkt',
#   'annehmen',
#   'Frage',
#   'Pendelapparate',
#   'Bestimmung',
#   'viel',
#   'punkten',
#   'vortheilhaftesten',
#   'besonder',
#   'Commission',
#   'Vorsitz',
#   'Baeyer',
#   'Herr',
#   'Bruhns',
#   'Hirsch',
#   'Oppolzer',
#   'Peter',
#   'Albrecht',
#   'bestehen',
#   'Bezug',
#   'Punkt',
#   'Ausführung',
#   'Pendelbeobachtungen',
#   'Höhe',
#   'Gebirge',
#   'erkennen',
#   'Conferenz',
#   'hoch',
#   'Werth',
#   'Untersuchung',
#   'sprechen',
#   'einstimmig',
#   'Wunsch',
#   'Durchbohrung',
#   'Alpe',
#   'benutzen',
#   'Pen-',
#   'geeignet',
#   'Punkt',
#   'Innern',
#   'Höhe',
#   'Gebirge',
#   'anstellen',
#   'Neubestimmung',
#   'Erddichtigkeit',
#   'erhalten',
#   'Herr',
#   'zuvor',
#   'hinweisen',
#   'Innern',
#   'Dichtigkeit',
#   'wahrscheinlich',
#   'Beitrag',
#   'Kenntniss',
#   'mittlern',
#   'erden',
#   'Untersuchung',
#   'erwarten',
#   'Herr',
#   'Bremiker',
#   'berichten',
#   'Punkt',
#   'Herr',
#   'Baeyer',
#   'Herrn',
#   'Perrier',
#   'Auskunft',
#   'Art',
#   'beweglich',
#   'Faden',
#   'erhalten',
#   'Herr',
#   'Villarceau',
#   'erwähnen',
#   'Erfahrung',
#   'Azimuthalbeobachtungen',
#   'Nacht',
#   'beziehen',
#   'Herr',
#   'Oppolger',
#   'Tagbeobachtungen',
#   'praktisch',
#   'Grund',
#   'hinzufügen',
#   'wünschen',
#   'Herr',
#   'Perrier',
#   'Wunsch',
#   'aussprechen',
#   'Geodäten',
#   'Astronom',
#   'Untersuchung',
#   'Nachtbeobachtungen',
#   'bethei-',
#   'mögen',
#   'Beschluss',
#   'annehmen',
#   'Conferenz',
#   'Veranlassung',
#   'Herrn',
#   'Perrier',
#   'auf-',
#   'merksam',
#   'Einführung',
#   'beweglich',
#   'Faden',
#   'liten',
#   'Voraussetzung',
#   'Unveränderlichkeit',
#   'Instrument',
#   'dauern',
#   'Messung',
#   'sorgen',
#   'Interesse',
#   'Herr',
#   'Perrier',
#   'Villarceau',
#   'Aussicht',
#   'gestellt',
#   'Versuch',
#   'entgegensehen',
#   'Frage',
#   'Tag-',
#   'Nachtbeobachtungen',
#   'vorziehen',
#   'ent-',
#   'scheiden',
#   'Herr',
#   'Tinter',
#   'Frage',
#   'Herr',
#   'Bruhms',
#   'bemerken',
#   'tungen',
#   'Insel',
#   'wünschenswerth',
#   'Herr',
#   'Versicherung',
#   'geben',
#   'trigonometrische',
#   'Nivellement',
#   'Insel',
#   'Helgoland',
#   'Festlande',
#   'einig',
#   'Centimeter',
#   'genau',
#   'ausführen',
#   'annehmen',
#   'Centralbureau',
#   'beauftragen',
#   'Commissare',
#   'Land',
#   'selbstregistrirende',
#   'Pegel',
#   'aufstellen',
#   'Circular',
#   'auffordern',
#   'Appa-',
#   'raten',
#   'gemacht',
#   'Erfahrung',
#   'erzielen',
#   'Resultat',
#   'genannt',
#   'Bureau',
#   'mitzutheilen',
#   'Grund',
#   'Beschluß',
#   'fassen',
#   'Frage',
#   'Festsetzung',
#   'international',
#   'Null-',
#   'punktes',
#   'jed',
#   'Land',
#   'einig',
#   'dauerhaft',
#   'versichern',
#   'Niveaumarken',
#   'lang',
#   'Debatte',
#   'Conferenz',
#   'folgend',
#   'Beschluss',
#   'gefasst',
#   'Pegelbeobachtungen',
#   'sowohl',
#   'Nivellements',
#   'definitive',
#   'Wahl',
#   'gemeinsam',
#   'beschränken',
#   'Conferenz',
#   'Commissären',
#   'Meer',
#   'gelegen',
#   'Land',
#   'Errichtung',
#   'möglichst',
#   'registrirenden',
#   'Pegel',
#   'empfehlen',
#   'halten',
#   'Conferenz',
#   'höchst',
#   'wünschenswerth',
#   'landen',
#   'solid',
#   'versichern',
#   'her-',
#   'stellen',
#   'Frage',
#   'stellen',
#   'Herr',
#   'Bruhns',
#   'Antrag',
#   'Conferenz',
#   'wünschen',
#   'Zusammenstellung',
#   'listen',
#   'Literatur',
#   'Gradmessungsarbeiten',
#   'Amendement',
#   'Herrn',
#   'Ferrero',
#   'Literatur',
#   'Europäische',
#   'Gradmessung',
#   'angehörig',
#   'Staat',
#   'soweit',
#   'hinzufügen',
#   'Antrag',
#   'annehmen',
#   'Herr',
#   'Bruhns',
#   'stellen',
#   'Antrag',
#   'Zusammenstellung',
#   'Coordinaten',
#   'fertig',
#   'astrono-',
#   'mischen',
#   'punkten',
#   'nebst',
#   'Angabe',
#   'orten',
#   'Pendelbeobachtungen',
#   'anstellen',
#   'Angabe',
#   'Titel',
#   'Publicationen',
#   'gleich',
#   'Weise',
#   'berichten',
#   'allgemein',
#   'Oonferenz',
#   'wünschen',
#   'Antrag',
#   'Amendement',
#   'Herrn',
#   'Villarcean',
#   'Coordinaten',
#   'soweit',
#   'geo-',
#   'dätischen',
#   'hinzufügen',
#   'annehmen',
#   'Antrag',
#   'Herrn',
#   '.Bruhns',
#   'Zusammenstellung',
#   'karten',
#   'ausgeführt',
#   'Dreieck',
#   'besonder',
#   'karten',
#   'ausgeführt',
#   'Nivellements',
#   'ersichtlich',
#   'erwünscht',
#   'beauftragen',
#   'Conferenz',
#   'Centralbureau',
#   'Aus-',
#   'führung',
#   'Herr',
#   'Commissare',
#   'gebeten',
#   'nöthigen',
#   'Datum',
#   'einsenden',
#   'Herr',
#   'Bauernfeind',
#   'Bruhns',
#   'allgemein',
#   'Conferenz',
#   'wolle',
#   'erklären',
#   'besonder',
#   'Publication',
#   'geodätisch',
#   'nivellitischen',
#   'Coordinaten',
#   'Land',
#   'unnöthig',
#   'erscheinen',
#   'vollständig',
#   'Verzeichniss',
#   'betreffend',
#   'Literatur',
#   'geben',
#   'da-',
#   'möglichst',
#   'rasch',
#   'Veröffentlichung',
#   'ausgeführt',
#   'Triangulationen',
#   'Präcisionsnivellements',
#   'wünschen',
#   'einstimmig',
#   'annehmen',
#   'Programm',
#   'Verhandlung',
#   'erledigen',
#   'Herr',
#   'Vecchi',
#   'berichten',
#   'topographischen',
#   'Karte',
#   'Italien',
#   'legen',
#   'verschieden',
#   'Sectionen',
#   'Conferenz',
#   'erheben',
#   'Antrag',
#   'Präsident',
#   'königlich',
#   'Sächsische',
#   'Regierung',
#   'mein',
#   'innig',
#   'Unterstützung',
#   'Aufnahme',
#   'auszu-',
#   'sprechen',
#   'Herr',
#   'Oppolzer',
#   'sprechen',
#   'Präsidium',
#   'Herr',
#   'Hügel',
#   'Herr',
#   'Perrier',
#   'Herrn',
#   'nageln',
#   'Herr',
#   'Bauernfeind',
#   'setzen',
#   'Sitzung',
#   'permanent',
#   'Commission',
#   'Nachmittag',
#   'Protokoll',
#   'verlesen',
#   'genehmigen',
#   'Schluss',
#   'Sitzung',
#   'Minute',
#   'Dresden',
#   'September',
#   'Forsch',
#   'Baeyer',
#   'Bauernfeind',
#   'Faye',
#   'Bruhns',
#   'Hirsch',
#   'drucken',
#   'Engelhardt',
#   'Leipzig',
#   'Protokoll',
#   'Verhandlung',
#   'permanent',
#   'Commission',
#   'Europäische',
#   'Gradmessung',
#   'September',
#   'Manuseript',
#   'drucken']]

# %% [markdown]
# Your way of processing the documents will likely vary; here, I only split on whitespace to tokenize, followed by lowercasing each word. In fact, I use this particular (simplistic and inefficient) setup to mimic the experiment done in [Deerwester et al.’s original LSA article](http://www.cs.bham.ac.uk/~pxt/IDA/lsa_ind.pdf) (Table 2).
#
# The ways to process documents are so varied and application- and language-dependent that I decided to not constrain them by any interface. Instead, a document is represented by the features extracted from it, not by its “surface” string form: how you get to the features is up to you. Below I describe one common, general-purpose approach (called bag-of-words), but keep in mind that different application domains call for different features, and, as always, it’s [garbage in, garbage out](https://en.wikipedia.org/wiki/Garbage_in,_garbage_out)...
#
# To convert documents to vectors, we’ll use a document representation called [bag-of-words](https://en.wikipedia.org/wiki/Bag-of-words_model). In this representation, each document is represented by one vector where a vector element `i` represents the number of times the `i`th word appears in the document.
#
# It is advantageous to represent the questions only by their (integer) ids. The mapping between the questions and ids is called a dictionary:

# %%
dictionary = corpora.Dictionary(texts)
dictionary.save(os.path.join(TEMP_FOLDER, 'deerwester.dict'))  # store the dictionary, for future reference
print(dictionary)
# Out:
# Dictionary(10829 unique tokens: ['.Bessel', '.auf', '16-', '1er', '1’Association']...)

# %% [markdown]
# Here we assigned a unique integer ID to all words appearing in the processed corpus with the [gensim.corpora.dictionary.Dictionary](https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary) class. This sweeps across the texts, collecting word counts and relevant statistics. In the end, we see there are twelve distinct words in the processed corpus, which means each document will be represented by twelve numbers (ie., by a 12-D vector). To see the mapping between words and their ids:

# %%
print(dictionary.token2id)
# Out:
# {'.Bessel': 0, '.auf': 1, '16-': 2, '1er': 3, '1’Association': 4, '6t6': 5, '6tait': 6, '6toiles': 7, 'Abends': 8, 'Ablenkung': 9, 'Ablesungsfehler': 10, 'Ablothungsfernrohrs': 11, 'Abtheilung': 12, 'Abweichung': 13, 'Aenderung': 14, 'Ainsi': 15, 'Albania': 16, 'Albrecht': 17, 'Alger': 18, 'Algerie': 19, 'Algier': 20, 'Alicante': 21, 'Alpi': 22, 'Altona': 23, 'Altonaer': 24, 'An-': 25, 'Anfang': 26, 'Angelegenheit': 27, 'Angelo': 28, 'Angriff': 29, 'Antrag': 30, 'Antwort': 31, 'Anwendung': 32, 'Anwesend': 33, 'Anzahl': 34, 'Apparat': 35, 'Appendix': 36, 'Ar-': 37, 'Arbeit': 38, 'Art': 39, 'Ascoli': 40, 'Asse': 41, 'Association': 42, 'Atri': 43, 'Aufnahme': 44, 'Aufstellung': 45, 'Aufstellungsort': 46, 'August': 47, 'Ausdehnungscoefficienten': 48, 'Ausführung': 49, 'Ausgabe': 50, 'Austria': 51, 'Auszug': 52, 'Ayant': 53, 'Azimuth': 54, 'Azimuthe': 55, 'Azimuthes': 56, 'Bad': 57, 'Baeyer': 58, 'Bairische': 59, 'Barogei': 60, 'Barozzi': 61, 'Basis': 62, 'Basisapparate': 63, 'Basisapparaten': 64, 'Basismessung': 65, 'Bauernfeind': 66, 'Bayerische': 67, 'Be-': 68, 'Bedauern': 69, 'Bedingung': 70, 'Behörde': 71, 'Bemerkung': 72, 'Beobach-': 73, 'Beobachter': 74, 'Beobachtung': 75, 'Beobachtungsreihen': 76, 'Berathung': 77, 'Berechnung': 78, 'Bericht': 79, 'Berlin': 80, 'Berlino': 81, 'Berücksichtigung': 82, 'Beschluß': 83, 'Bessel': 84, 'Bestimmung': 85, 'Biccari': 86, 'Bien': 87, 'Biskra': 88, 'Boden': 89, 'Boden-': 90, 'Bogensecunde': 91, 'Borisogljebsk': 92, 'Breite': 93, 'Brest': 94, 'Brindisi': 95, 'Brocken': 96, 'Bruhms': 97, 'Bruhns': 98, 'Bureau': 99, 'Bus': 100, 'Böne': 101, 'Börsch': 102, 'Calabria': 103, 'Campagne': 104, 'Capitain': 105, 'Capitaine': 106, 'Capitano': 107, 'Capni': 108, 'Capno': 109, 'Capo': 110, 'Capopassaro': 111, 'Carcassonne': 112, 'Carte': 113, 'Castania': 114, 'Catania': 115, 'Caucase': 116, 'Central-': 117, 'Centralbureau': 118, 'Centralbureaus': 119, 'Centrirung': 120, 'Cependant': 121, 'Cette': 122, 'Chef': 123, 'Circular': 124, 'Come': 125, 'Commis-': 126, 'Commissare': 127, 'Commissaren': 128, 'Commission': 129, 'Commissione': 130, 'Comparator': 131, 'Comptes-rendus': 132, 'Conferenz': 133, 'Construction': 134, 'Coordinaten': 135, 'Corfu': 136, 'Corpo': 137, 'Corsica': 138, 'Crati': 139, 'DEL': 140, 'DETERMINATION': 141, 'Dai': 142, 'Dal': 143, 'Dans': 144, 'Datum': 145, 'Declination': 146, 'Del': 147, 'Delambre': 148, 'Delaunay': 149, 'Detail': 150, 'Deux': 151, 'Diffe-': 152, 'Differenz': 153, 'Director': 154, 'Direttore': 155, 'Discussion': 156, 'Dobner': 157, 'Donati': 158, 'Dr.': 159, 'Drei-': 160, 'Dreieck': 161, 'Dreieckskette': 162, 'Dreiecksketten': 163, 'Dreieckspunkt': 164, 'Dreieckspunkte': 165, 'Dreieckspunkten': 166, 'Dresden': 167, 'Dunkergue': 168, 'EUROPEO': 169, 'Eger': 170, 'Ehre': 171, 'Ein-': 172, 'Einfluss': 173, 'Einladung': 174, 'Einrichtung': 175, 'Einwirkung': 176, 'Eisenbahnen': 177, 'Elfenbein': 178, 'Elfenbeinkugel': 179, 'Elle': 180, 'End-': 181, 'Endresultat': 182, 'Enfin': 183, 'Engelhardt': 184, 'Entwurf': 185, 'Erdoberfläche': 186, 'Ergänzung': 187, 'Erklärung': 188, 'Erledigung': 189, 'Errichtung': 190, 'Ersuchen': 191, 'Ertel': 192, 'Espagne': 193, 'Esso': 194, 'Est': 195, 'Etat-major': 196, 'Europe': 197, 'Europäische': 198, 'Excel-': 199, 'Excellenz': 200, 'Exemplar': 201, 'Fade': 202, 'Faden': 203, 'Fadenpendel': 204, 'Fallstein': 205, 'Fand': 206, 'Far': 207, 'Fassung': 208, 'Fehlergrenze': 209, 'Feldarbeiten': 210, 'Ferner': 211, 'Fernröhre': 212, 'Fhigely': 213, 'Figur': 214, 'Finanzminister': 215, 'Fixpunkt': 216, 'Fixsterne': 217, 'Fligely': 218, 'Foggia': 219, 'Folge': 220, 'Forsch': 221, 'Fortgang': 222, 'Fortschritt': 223, 'Frage': 224, 'France': 225, 'Frankreich': 226, 'Freude': 227, 'Fun': 228, 'Fuss': 229, 'GRADO': 230, 'Ganahl': 231, 'Gang': 232, 'Gauss': 233, 'Gegend': 234, 'Gegenstand': 235, 'Gegenwart': 236, 'Genauigkeit': 237, 'Genehmigung': 238, 'General': 239, 'General-': 240, 'General-Bericht': 241, 'Generalbericht': 242, 'Generalconferen ...

# %% [markdown]
# To actually convert tokenized documents to vectors:

# %%
new_doc = "Anwesend Pascal"
new_vec = dictionary.doc2bow(new_doc.lower().split())
print(new_vec)  # the word "Pascal" does not appear in the dictionary and is ignored
# Out:
# [(688, 1)]

# %% [markdown]
# The function `doc2bow()` simply counts the number of occurrences of each distinct word, converts the word to its integer word id and returns the result as a bag-of-words--a sparse vector, in the form of `[(word_id, word_count), ...]`.
#
# As the token_id is 0 for *"human"* and 2 for *"computer"*, the new document *“Human computer interaction”* will be transformed to [(0, 1), (2, 1)]. The words *"computer"* and *"human"* exist in the dictionary and appear once. Thus, they become (0, 1), (2, 1) respectively in the sparse vector. The word *"interaction"* doesn't exist in the dictionary and, thus, will not show up in the sparse vector. The other ten dictionary words, that appear (implicitly) zero times, will not show up in the sparse vector and , ,there will never be a element in the sparse vector like (3, 0).
#
# For people familiar with scikit learn, `doc2bow()` has similar behaviors as calling `transform()` on [`CountVectorizer`](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html). `doc2bow()` can behave like `fit_transform()` as well. For more details, please look at [gensim API Doc](https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.doc2bow).

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
corpora.MmCorpus.serialize(os.path.join(TEMP_FOLDER, 'deerwester.mm'), corpus)  # store to disk, for later use
for c in corpus:
    print(c)
# Out:
# 2019-05-25 15:37:52,123 : INFO : storing corpus in Matrix Market format to /tmp/deerwester.mm
# 2019-05-25 15:37:52,125 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-05-25 15:37:52,127 : INFO : saving sparse matrix to /tmp/deerwester.mm
# 2019-05-25 15:37:52,128 : INFO : PROGRESS: saving document #0
# 2019-05-25 15:37:52,131 : INFO : saved 9x12 matrix, density=25.926% (28/108)
# 2019-05-25 15:37:52,134 : INFO : saving MmCorpus index to /tmp/deerwester.mm.index
# 2019-05-25 15:37:52,135 : WARNING : this function is deprecated, use smart_open.open instead
# [(0, 1), (1, 1), (2, 1)]
# [(0, 1), (3, 1), (4, 1), (5, 1), (6, 1), (7, 1)]
# [(2, 1), (5, 1), (7, 1), (8, 1)]
# [(1, 1), (5, 2), (8, 1)]
# [(3, 1), (6, 1), (7, 1)]
# [(9, 1)]
# [(9, 1), (10, 1)]
# [(9, 1), (10, 1), (11, 1)]
# [(4, 1), (10, 1), (11, 1)]

# %% [markdown]
# By now it should be clear that the vector feature with `id=10` represents the number of times the word "graph" occurs in the document.  The answer is “zero” for the first six documents and “one” for the remaining three. As a matter of fact, we have arrived at exactly the same corpus of vectors as in the [Quick Example](https://radimrehurek.com/gensim/tutorial.html#first-example). If you're running this notebook yourself the word IDs may differ, but you should be able to check the consistency between documents comparing their vectors.
#
# ## Corpus Streaming – One Document at a Time
#
# Note that *corpus* above resides fully in memory, as a plain Python list. In this simple example, it doesn’t matter much, but just to make things clear, let’s assume there are millions of documents in the corpus. Storing all of them in RAM won’t do. Instead, let’s assume the documents are stored in a file on disk, one document per line. Gensim only requires that a corpus be able to return one document vector at a time:

# %%
from smart_open import smart_open
class MyCorpus(object):
    def __iter__(self):
        for line in smart_open(filename, 'rb'):
            # assume there's one document per line, tokens separated by whitespace
            yield dictionary.doc2bow(line.lower().split())

# %% [markdown]
# The assumption that each document occupies one line in a single file is not important; you can design the `__iter__` function to fit your input format, whatever that may be - walking directories, parsing XML, accessing network nodes... Just parse your input to retrieve a clean list of tokens in each document, then convert the tokens via a dictionary to their IDs and yield the resulting sparse vector inside `__iter__`.

# %%
corpus_memory_friendly = MyCorpus() # doesn't load the corpus into memory!
print(corpus_memory_friendly)
# Out:
# <__main__.MyCorpus object at 0x7f72e467b080>

# %% [markdown]
# `corpus_memory_friendly` is now an object. We didn’t define any way to print it, so `print` just outputs address of the object in memory. Not very useful. To see the constituent vectors, let’s iterate over the corpus and print each document vector (one at a time):

# %%
for vector in corpus_memory_friendly:  # load one vector into memory at a time
    print(vector)
# Out:
# [(1, 2), (2, 2), (3, 6), (5, 17), (6, 4), (7, 3), (632, 3), (633, 7), (634, 4), (635, 4), (636, 14), (637, 56), (638, 17), (639, 3), (640, 31), (641, 7), (642, 2), (643, 2), (644, 10), (645, 3), (646, 2), (647, 6), (648, 2), (649, 8), (650, 14), (651, 31), (652, 4), (653, 6), (654, 3), (655, 9), (656, 27), (657, 3), (658, 9), (659, 13), (660, 74), (661, 2), (662, 2), (663, 7), (664, 2), (665, 3), (666, 11), (667, 2), (668, 2), (669, 4), (670, 7), (671, 24), (672, 2), (673, 3), (674, 2), (675, 3), (676, 15), (677, 12), (678, 158), (679, 6), (680, 13), (681, 3), (682, 7), (683, 26), (684, 28), (685, 8), (686, 60), (687, 37), (688, 53), (689, 6), (690, 3), (691, 4), (692, 4), (693, 4), (694, 2), (695, 6), (696, 22), (697, 9), (698, 36), (699, 6), (700, 7), (701, 2), (702, 7), (703, 2), (704, 23), (705, 4), (706, 27), (707, 174), (708, 36), (709, 69), (710, 2), (711, 2), (712, 4), (713, 4), (714, 2), (715, 2), (716, 3), (717, 5), (718, 15), (719, 5), (720, 6), (721, 45), (722, 9), (723, 71), (724, 4), (725, 2), (726, 4), (727, 11), (728, 2), (729, 3), (730, 10), (731, 85), (732, 4), (733, 28), (734, 6), (735, 217), (736, 10), (737, 8), (738, 135), (739, 16), (740, 47), (741, 6), (742, 2), (743, 3), (744, 25), (745, 23), (746, 111), (747, 9), (748, 22), (749, 10), (750, 116), (751, 26), (752, 16), (753, 20), (754, 28), (755, 3), (756, 11), (757, 27), (758, 63), (759, 27), (760, 2), (761, 167), (762, 3), (763, 11), (764, 22), (765, 4), (766, 14), (767, 18), (768, 4), (769, 108), (770, 8), (771, 7), (772, 7), (773, 5), (774, 4), (775, 7), (776, 5), (777, 5), (778, 5), (779, 116), (780, 173), (781, 5), (782, 78), (783, 9), (784, 281), (785, 134), (786, 8), (787, 34), (788, 8), (789, 2), (790, 84), (791, 7), (792, 5), (793, 14), (794, 218), (795, 9), (796, 24), (797, 70), (798, 46), (799, 7), (800, 21), (801, 46), (802, 41), (803, 35), (804, 5), (805, 47), (806, 31), (807, 6), (808, 41), (809, 2), (810, 19), (811, 95), (812, 106), (813, 15), (814, 3), (815, 6), (816, 7), (817, 10), (818, 9), (819, 13), (820, 8), (821, 2), (822, 8), (823, 5), (824, 26), (825, 4), (826, 16), (827, 3), (828, 16), (829, 47), (830, 2), (831, 8), (832, 7), (833, 2), (834, 4), (835, 3), (836, 2), (837, 82), (838, 27), (839, 111), (840, 12), (841, 20), (842, 48), (843, 4), (844, 4), (845, 3), (846, 2), (847, 2), (848, 2), (849, 3), (850, 5), (851, 2), (852, 5), (853, 29), (854, 2), (855, 2), (856, 7), (857, 54), (858, 2), (859, 7), (860, 7), (861, 5), (862, 2), (863, 5), (864, 3), (865, 25), (866, 9), (867, 4), (868, 2), (869, 5), (870, 5), (871, 4), (872, 12), (873, 20), (874, 19), (875, 5), (876, 9), (877, 6), (878, 7), (879, 23), (880, 2), (881, 3), (882, 7), (883, 3), (884, 15), (885, 8), (886, 3), (887, 5), (888, 2), (889, 2), (890, 5), (891, 8), (892, 2), (893, 6), (894, 2), (895, 3), (896, 2), (897, 2), (898, 3), (899, 4), (900, 8), (901, 5), (902, 2), (903, 2), (904, 14), (905, 2), (906, 4), (907, 4), (908, 2), (909, 5), (910, 4), (911, 2), (912, 14), (913, 19), (914, 6), (915, 22), (916, 9), (917, 11), (918, 46), (919, 257), (920, 2), (921, 2), (922, 4), (923, 31), (924, 13), (925, 2), (926, 2), (927, 2), (928, 12), (929, 4), (930, 54), (931, 17), (932, 31), (933, 21), (934, 3), (935, 8), (936, 2), (937, 10), (938, 3), (939, 24), (940, 10), (941, 2), (942, 12), (943, 11), (944, 2), (945, 4), (946, 5), (947, 27), (948, 12), (949, 3), (950, 11), (951, 7), (952, 28), (953, 75), (954, 4), (955, 2), (956, 2), (957, 4), (958, 3), (959, 6), (960, 3), (961, 3), (962, 2), (963, 3), (964, 2), (965, 2), (966, 2), (967, 3), (968, 5), (969, 8), (970, 5), (971, 15), (972, 10), (973, 3), (974, 2), (975, 4), (976, 2), (977, 5), (978, 29), (979, 4), (980, 16), (981, 17), (982, 2), (983, 5), (984, 7), (985, 15), (986, 4), (987, 2), (988, 2), (989, 5), (990, 15), (991, 3), (992, 6), (993, 4), (994, 5), (995, 70), (996, 7), (997, 11), (998, 3), (999, 3), (1000, 100), (1001, 8), (1002, 2), (1003, 4), (1004, 3), (1005, 2), (1006, 2), (1007, 5), (1008, 34), (1009, 2), (1010 ...

# %% [markdown]
# Although the output is the same as for the plain Python list, the corpus is now much more memory friendly, because at most one vector resides in RAM at a time. Your corpus can now be as large as you want.
#
# We are going to create the dictionary from the mycorpus.txt file without loading the entire file into memory. Then, we will generate the list of token ids to remove from this dictionary by querying the dictionary for the token ids of the stop words, and by querying the document frequencies dictionary (`dictionary.dfs`) for token ids that only appear once. Finally, we will filter these token ids out of our dictionary. Keep in mind that `dictionary.filter_tokens` (and some other functions such as `dictionary.add_document`) will call `dictionary.compactify()` to remove the gaps in the token id series thus enumeration of remaining tokens can be changed.

# %%
from six import iteritems
from smart_open import smart_open

# collect statistics about all tokens
dictionary = corpora.Dictionary(line.lower().split() for line in smart_open(filename, 'rb'))

once_ids = [tokenid for tokenid, docfreq in iteritems(dictionary.dfs) if docfreq == 1]

# remove stop words and words that appear only once
dictionary.filter_tokens(once_ids)
print(dictionary)
# Out:
# Dictionary(0 unique tokens: [])

# %% [markdown]
# And that is all there is to it! At least as far as bag-of-words representation is concerned. Of course, what we do with such a corpus is another question; it is not at all clear how counting the frequency of distinct words could be useful. As it turns out, it isn’t, and we will need to apply a transformation on this simple representation first, before we can use it to compute any meaningful document vs. document similarities. Transformations are covered in the [next tutorial](https://radimrehurek.com/gensim/tut2.html), but before that, let’s briefly turn our attention to *corpus persistency*.
#
# ## Corpus Formats
#
# There exist several file formats for serializing a Vector Space corpus (~sequence of vectors) to disk. *Gensim* implements them via the *streaming corpus interface* mentioned earlier: documents are read from (or stored to) disk in a lazy fashion, one document at a time, without the whole corpus being read into main memory at once.
#
# One of the more notable file formats is the [Matrix Market format](http://math.nist.gov/MatrixMarket/formats.html). To save a corpus in the Matrix Market format:

# %% [markdown]
# Other formats include [Joachim’s SVMlight format](http://svmlight.joachims.org/), [Blei’s LDA-C format](http://www.cs.columbia.edu/~blei/lda-c/) and [GibbsLDA++ format](http://gibbslda.sourceforge.net/).

# %%
corpora.SvmLightCorpus.serialize(os.path.join(TEMP_FOLDER, 'corpus.svmlight'), corpus)
corpora.BleiCorpus.serialize(os.path.join(TEMP_FOLDER, 'corpus.lda-c'), corpus)
corpora.LowCorpus.serialize(os.path.join(TEMP_FOLDER, 'corpus.low'), corpus)

# %% [markdown]
# Conversely, to load a corpus iterator from a Matrix Market file:

# %%
corpus = corpora.MmCorpus(os.path.join(TEMP_FOLDER, 'corpus.mm'))

# %% [markdown]
# Corpus objects are streams, so typically you won’t be able to print them directly:

# %%
print(corpus)
# Out:
# MmCorpus(2 documents, 2 features, 1 non-zero entries)

# %% [markdown]
# Instead, to view the contents of a corpus:

# %%
# one way of printing a corpus: load it entirely into memory
print(list(corpus))  # calling list() will convert any sequence to a plain Python list
# Out:
# [[(1, 0.5)], []]

# %% [markdown]
# or

# %%
# another way of doing it: print one document at a time, making use of the streaming interface
for doc in corpus:
    print(doc)
# Out:
# [(1, 0.5)]
# []

# %% [markdown]
# The second way is obviously more memory-friendly, but for testing and development purposes, nothing beats the simplicity of calling `list(corpus)`.
#
# To save the same Matrix Market document stream in Blei’s LDA-C format,

# %%
corpora.BleiCorpus.serialize(os.path.join(TEMP_FOLDER, 'corpus.lda-c'), corpus)

# %% [markdown]
# In this way, *gensim* can also be used as a memory-efficient **I/O format conversion tool**: just load a document stream using one format and immediately save it in another format. Adding new formats is dead easy, check out the [code for the SVMlight corpus](https://github.com/piskvorky/gensim/blob/develop/gensim/corpora/svmlightcorpus.py) for an example.
#
# ## Compatibility with NumPy and SciPy
#
# Gensim also contains [efficient utility functions](http://radimrehurek.com/gensim/matutils.html) to help converting from/to `numpy` matrices:

# %%
import gensim
import numpy as np
numpy_matrix = np.random.randint(10, size=[5,2])
corpus = gensim.matutils.Dense2Corpus(numpy_matrix)
numpy_matrix_dense = gensim.matutils.corpus2dense(corpus, num_terms=10)

# %% [markdown]
# and from/to `scipy.sparse` matrices:

# %%
import scipy.sparse
scipy_sparse_matrix = scipy.sparse.random(5,2)
corpus = gensim.matutils.Sparse2Corpus(scipy_sparse_matrix)
scipy_csc_matrix = gensim.matutils.corpus2csc(corpus)

# %% [markdown]
# For a complete reference (want to prune the dictionary to a smaller size? Optimize converting between corpora and NumPy/SciPy arrays?), see the [API documentation](https://radimrehurek.com/gensim/apiref.html). Or continue to the next tutorial on Topics and Transformations ([notebook](Topics_and_Transformations.ipynb)
# or [website](https://radimrehurek.com/gensim/tut2.html)).
